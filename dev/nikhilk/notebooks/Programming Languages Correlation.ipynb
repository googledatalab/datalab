# %% [markdown]
# # Programming Languages Correlation
# _If you program in x, are you likely to program in y_

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import json
import gcp.bigquery as bq
import gcp.interactive

# %% [markdown]
# ## Understanding the Data
#
# We're going to work with the GitHub Archive project data - it contains all github events - commits, pushes, forks, watches etc. as a timeline tables.
#
# First, lets check out the schema.
#
# **Future note**: Later on we'll add a way to sample the table as well, and display data along with information about distribution of data in a column, maybe outliers etc. to get an even more in-depth sense of the stored data.

# %%
table = bq.table('githubarchive:github.timeline')
table.schema()
# Out:
# [<gcp.bigquery._table._Field at 0x1082b3190>,
#  <gcp.bigquery._table._Field at 0x1082b31d0>,
#  <gcp.bigquery._table._Field at 0x1082b3210>,
#  <gcp.bigquery._table._Field at 0x1082b3250>,
#  <gcp.bigquery._table._Field at 0x1082b3290>,
#  <gcp.bigquery._table._Field at 0x1082b32d0>,
#  <gcp.bigquery._table._Field at 0x1082b3310>,
#  <gcp.bigquery._table._Field at 0x1082b3350>,
#  <gcp.bigquery._table._Field at 0x1082b3390>,
#  <gcp.bigquery._table._Field at 0x1082b33d0>,
#  <gcp.bigquery._table._Field at 0x1082b3410>,
#  <gcp.bigquery._table._Field at 0x1082b3450>,
#  <gcp.bigquery._table._Field at 0x1082b3490>,
#  <gcp.bigquery._table._Field at 0x1082b34d0>,
#  <gcp.bigquery._table._Field at 0x1082b3510>,
#  <gcp.bigquery._table._Field at 0x1082b3550>,
#  <gcp.bigquery._table._Field at 0x1082b3590>,
#  <gcp.bigquery._table._Field at 0x1082b35d0>,
#  <gcp.bigquery._table._Field at 0x1082b3610>,
#  <gcp.bigquery._table._Field at 0x1082b3650>,
#  <gcp.bigquery._table._Field at 0x1082b3690>,
#  <gcp.bigquery._table._Field at 0x1082b36d0>,
#  <gcp.bigquery._table._Field at 0x1082b3710>,
#  <gcp.bigquery._table._Field at 0x1082b3750>,
#  <gcp.bigquery._table._Field at 0x1082b3790>,
#  <gcp.bigquery._table._Field at 0x1082b37d0>,
#  <gcp.bigquery._table._Field at 0x1082b3810>,
#  <gcp.bigquery._table._Field at 0x1082b3850>,
#  <gcp.bigquery._table._Field at 0x1082b3890>,
#  <gcp.bigquery._table._Field at 0x1082b38d0>,
#  <gcp.bigquery._table._Field at 0x1082b3910>,
#  <gcp.bigquery._table._Field at 0x1082b3950>,
#  <gcp.bigquery._table._Field at 0x1082b3990>,
#  <gcp.bigquery._table._Field at 0x1082b39d0>,
#  <gcp.bigquery._table._Field at 0x1082b3a10>,
#  <gcp.bigquery._table._Field at 0x1082b3a50>,
#  <gcp.bigquery._table._Field at 0x1082b3a90>,
#  <gcp.bigquery._table._Field at 0x1082b3ad0>,
#  <gcp.bigquery._table._Field at 0x1082b3b10>,
#  <gcp.bigquery._table._Field at 0x1082b3b50>,
#  <gcp.bigquery._table._Field at 0x1082b3b90>,
#  <gcp.bigquery._table._Field at 0x1082b3bd0>,
#  <gcp.bigquery._table._Field at 0x1082b3c10>,
#  <gcp.bigquery._table._Field at 0x1082b3c50>,
#  <gcp.bigquery._table._Field at 0x1082b3c90>,
#  <gcp.bigquery._table._Field at 0x1082b3cd0>,
#  <gcp.bigquery._table._Field at 0x1082b3d10>,
#  <gcp.bigquery._table._Field at 0x1082b3d50>,
#  <gcp.bigquery._table._Field at 0x1082b3d90>,
#  <gcp.bigquery._table._Field at 0x1082b3dd0>,
#  <gcp.bigquery._table._Field at 0x1082b3e10>,
#  <gcp.bigquery._table._Field at 0x1082b3e50>,
#  <gcp.bigquery._table._Field at 0x1082b3e90>,
#  <gcp.bigquery._table._Field at 0x1082b3ed0>,
#  <gcp.bigquery._table._Field at 0x1082b3f10>,
#  <gcp.bigquery._table._Field at 0x1082b3f50>,
#  <gcp.bigquery._table._Field at 0x1082b3f90>,
#  <gcp.bigquery._table._Field at 0x1082b3fd0>,
#  <gcp.bigquery._table._Field at 0x1082c8050>,
#  <gcp.bigquery._table._Field at 0x1082c8090>,
#  <gcp.bigquery._table._Field at 0x1082c80d0>,
#  <gcp.bigquery._table._Field at 0x1082c8110>,
#  <gcp.bigquery._table._Field at 0x1082c8150>,
#  <gcp.bigquery._table._Field at 0x1082c8190>,
#  <gcp.bigquery._table._Field at 0x1082c81d0>,
#  <gcp.bigquery._table._Field at 0x1082c8210>,
#  <gcp.bigquery._table._Field at 0x1082c8250>,
#  <gcp.bigquery._table._Field at 0x1082c8290>,
#  <gcp.bigquery._table._Field at 0x1082c82d0>,
#  <gcp.bigquery._table._Field at 0x1082c8310>,
#  <gcp.bigquery._table._Field at 0x1082c8350>,
#  <gcp.bigquery._table._Field at 0x1082c8390>,
#  <gcp.bigquery._table._Field at 0x1082c83d0>,
#  <gcp.bigquery._table._Field at 0x1082c8410>,
#  <gcp.bigquery._table._Field at 0x1082c8450>,
#  <gcp.bigquery._table._Field at 0x1082c8490>,
#  <gcp.bigquery._table._Field at 0x1082c84d0>,
#  <gcp.bigquery._table._Field at 0x1082c8510>,
#  <gcp.bigquery._table._Field at 0x1082c8550>,
#  <gcp.bigquery._table._Field at 0x1082c8590>,
#  <gcp.bigquery._table._Field at 0x1082c85d0>,
#  <gcp.bigquery._table._Field at 0x1082c8610>,
#  <gcp.bigquery._table._Field at 0x1082c8650>,
#  <gcp.bigquery._table._Field at 0x1082c8690>,
#  <gcp.bigquery._table._Field at 0x1082c86d0>,
#  <gcp.bigquery._table._Field at 0x1082c8710>,
#  <gcp.bigquery._table._Field at 0x1082c8750>,
#  <gcp.bigquery._table._Field at 0x1082c8790>,
#  <gcp.bigquery._table._Field at 0x1082c87d0>,
#  <gcp.bigquery._table._Field at 0x1082c8810>,
#  <gcp.bigquery._table._Field at 0x1082c8850>,
#  <gcp.bigquery._table._Field at 0x1082c8890>,
#  <gcp.bigquery._table._Field at 0x1082c88d0>,
#  <gcp.bigquery._table._Field at 0x1082c8910>,
#  <gcp.bigquery._table._Field at 0x1082c8950>,
#  <gcp.bigquery._table._Field at 0x1082c8990>,
#  <gcp.bigquery._table._Field at 0x1082c89d0>,
#  <gcp.bigquery._table._Field at 0x1082c8a10>,
#  <gcp.bigquery._table._Field at 0x1082c8a50>,
#  <gcp.bigquery._table._Field at 0x1082c8a90>,
#  <gcp.bigquery._table._Field at 0x1082c8ad0>,
#  <gcp.bigquery._table._Field at 0x1082c8b10>,
#  <gcp.bigquery._table._Field at 0x1082c8b50>,
#  <gcp.bigquery._table._Field at 0x1082c8b90>,
#  <gcp.bigquery._table._Field at 0x1082c8bd0>,
#  <gcp.bigquery._table._Field at 0x1082c8c10>,
#  <gcp.bigquery._table._Field at 0x1082c8c50>,
#  <gcp.bigquery._table._Field at 0x1082c8c90>,
#  <gcp.bigquery._table._Field at 0x1082c8cd0>,
#  <gcp.bigquery._table._Field at 0x1082c8d10>,
#  <gcp.bigquery._table._Field at 0x1082c8d50>,
#  <gcp.bigquery._table._Field at 0x1082c8d90>,
#  <gcp.bigquery._table._Field at 0x1082c8dd0>,
#  <gcp.bigquery._table._Field at 0x1082c8e10>,
#  <gcp.bigquery._table._Field at 0x1082c8e50>,
#  <gcp.bigquery._table._Field at 0x1082c8e90>,
#  <gcp.bigquery._table._Field at 0x1082c8ed0>,
#  <gcp.bigquery._table._Field at 0x1082c8f10>,
#  <gcp.bigquery._table._Field at 0x1082c8f50>,
#  <gcp.bigquery._table._Field at 0x1082c8f90>,
#  <gcp.bigquery._table._Field at 0x1082c8fd0>,
#  <gcp.bigquery._table._Field at 0x1082cd050>,
#  <gcp.bigquery._table._Field at 0x1082cd090>,
#  <gcp.bigquery._table._Field at 0x1082cd0d0>,
#  <gcp.bigquery._table._Field at 0x1082cd110>,
#  <gcp.bigquery._table._Field at 0x1082cd150>,
#  <gcp.bigquery._table._Field at 0x1082cd190>,
#  <gcp.bigquery._table._Field at 0x1082cd1d0>,
#  <gcp.bigquery._table._Field at 0x1082cd210>,
#  <gcp.bigquery._table._Field at 0x1082cd250>,
#  <gcp.bigquery._table._Field at 0x1082cd290>,
#  <gcp.bigquery._table._Field at 0x1082cd2d0>,
#  <gcp.bigquery._table._Field at 0x1082cd310>,
#  <gcp.bigquery._table._Field at 0x1082cd350>,
#  <gcp.bigquery._table._Field at 0x1082cd390>,
#  <gcp.bigquery._table._Field at 0x1082cd3d0>,
#  <gcp.bigquery._table._Field at 0x1082cd410>,
#  <gcp.bigquery._table._Field at 0x1082cd450>,
#  <gcp.bigquery._table._Field at 0x1082cd490>,
#  <gcp.bigquery._table._Field at 0x1082cd4d0>,
#  <gcp.bigquery._table._Field at 0x1082cd510>,
#  <gcp.bigquery._table._Field at 0x1082cd550>,
#  <gcp.bigquery._table._Field at 0x1082cd590>,
#  <gcp.bigquery._table._Field at 0x1082cd5d0>,
#  <gcp.bigquery._table._Field at 0x1082cd610>,
#  <gcp.bigquery._table._Field at 0x1082cd650>,
#  <gcp.bigquery._table._Field at 0x1082cd690>,
#  <gcp.bigquery._table._Field at 0x1082cd6d0>,
#  <gcp.bigquery._table._Field at 0x1082cd710>,
#  <gcp.bigquery._table._Field at 0x1082cd750>,
#  <gcp.bigquery._table._Field at 0x1082cd790>,
#  <gcp.bigquery._table._Field at 0x1082cd7d0>,
#  <gcp.bigquery._table._Field at 0x1082cd810>,
#  <gcp.bigquery._table._Field at 0x1082cd850>,
#  <gcp.bigquery._table._Field at 0x108256cd0>,
#  <gcp.bigquery._table._Field at 0x1082859d0>,
#  <gcp.bigquery._table._Field at 0x108285990>,
#  <gcp.bigquery._table._Field at 0x108285ad0>,
#  <gcp.bigquery._table._Field at 0x108285a50>,
#  <gcp.bigquery._table._Field at 0x108285a10>,
#  <gcp.bigquery._table._Field at 0x1082cd890>,
#  <gcp.bigquery._table._Field at 0x1082cd8d0>,
#  <gcp.bigquery._table._Field at 0x1082cd910>,
#  <gcp.bigquery._table._Field at 0x1082cd950>,
#  <gcp.bigquery._table._Field at 0x1082cd990>,
#  <gcp.bigquery._table._Field at 0x1082cd9d0>,
#  <gcp.bigquery._table._Field at 0x1082cda10>,
#  <gcp.bigquery._table._Field at 0x1082cda50>,
#  <gcp.bigquery._table._Field at 0x1082cda90>,
#  <gcp.bigquery._table._Field at 0x1082cdad0>,
#  <gcp.bigquery._table._Field at 0x1082cdb10>,
#  <gcp.bigquery._table._Field at 0x1082cdb50>,
#  <gcp.bigquery._table._Field at 0x1082cdb90>,
#  <gcp.bigquery._table._Field at 0x1082cdbd0>,
#  <gcp.bigquery._table._Field at 0x1082cdc10>,
#  <gcp.bigquery._table._Field at 0x1082cdc50>,
#  <gcp.bigquery._table._Field at 0x1082cdc90>,
#  <gcp.bigquery._table._Field at 0x1082cdcd0>,
#  <gcp.bigquery._table._Field at 0x1082cdd10>,
#  <gcp.bigquery._table._Field at 0x1082cdd50>,
#  <gcp.bigquery._table._Field at 0x1082cdd90>,
#  <gcp.bigquery._table._Field at 0x1082cddd0>,
#  <gcp.bigquery._table._Field at 0x1082cde10>,
#  <gcp.bigquery._table._Field at 0x1082cde50>,
#  <gcp.bigquery._table._Field at 0x1082cde90>,
#  <gcp.bigquery._table._Field at 0x1082cded0>,
#  <gcp.bigquery._table._Field at 0x1082cdf10>,
#  <gcp.bigquery._table._Field at 0x1082cdf50>,
#  <gcp.bigquery._table._Field at 0x1082cdf90>,
#  <gcp.bigquery._table._Field at 0x1082cdfd0>,
#  <gcp.bigquery._table._Field at 0x1082d2050>,
#  <gcp.bigquery._table._Field at 0x1082d2090>,
#  <gcp.bigquery._table._Field at 0x1082d20d0>,
#  <gcp.bigquery._table._Field at 0x1082d2110>,
#  <gcp.bigquery._table._Field at 0x1082d2150>,
#  <gcp.bigquery._table._Field at 0x1082d2190>,
#  <gcp.bigquery._table._Field at 0x1082d21d0>,
#  <gcp.bigquery._table._Field at 0x1082d2210>,
#  <gcp.bigquery._table._Field at 0x1082d2250>]

# %% [markdown]
# ## Querying the Data
#
# Notice the integration of SQL into the notebook - its just SQL in a first-class form. We'll be adding colorization, syntax checking in the future.
#
# Queries do not execute when defined, but rather when `results()` is explicitly called. This allows composing complex queries more easily.
#
# Here we're finding the top-25 popular languages, based on number of pushes over the last year.

# %% [markdown]
# ### Iterative exploration and query refining

# %%
table.sample(fields=['repository_name', 'repository_language', 'created_at', 'type'])
# Out:
# [{u'created_at': u'2014-04-21 00:04:48',
#   u'repository_language': u'C++',
#   u'repository_name': u'shmup',
#   u'type': u'PushEvent'},
#  {u'created_at': u'2014-04-21 00:04:48',
#   u'repository_language': u'CSS',
#   u'repository_name': u'Overload-Grid',
#   u'type': u'PushEvent'},
#  {u'created_at': u'2014-04-21 00:04:47',
#   u'repository_language': u'C',
#   u'repository_name': u'BurdOS',
#   u'type': u'IssueCommentEvent'},
#  {u'created_at': u'2014-04-21 00:04:47',
#   u'repository_language': u'Python',
#   u'repository_name': u'Inf123TestPygame',
#   u'type': u'PushEvent'},
#  {u'created_at': u'2014-04-21 00:04:47',
#   u'repository_language': u'PHP',
#   u'repository_name': u'tc-site',
#   u'type': u'PushEvent'}]

# %%
# %%bq_sql
# SELECT repository_name, type, created_at, repository_language
# FROM [githubarchive:github.timeline]
# WHERE type = 'CreateEvent'
# LIMIT 5
# Out:
# [{u'created_at': u'2014-05-09 13:05:25',
#   u'repository_language': None,
#   u'repository_name': u'Tanki',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-05-09 13:05:25',
#   u'repository_language': None,
#   u'repository_name': u'mabster',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-05-09 13:05:24',
#   u'repository_language': u'JavaScript',
#   u'repository_name': u'pentaho-platform-plugin-common-ui',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-05-09 13:05:24',
#   u'repository_language': None,
#   u'repository_name': u'proyecto',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-05-09 13:05:23',
#   u'repository_language': u'Shell',
#   u'repository_name': u'ci-monkey',
#   u'type': u'CreateEvent'}]

# %%
# %%bq_sql
# SELECT repository_name, type, created_at, repository_language
# FROM [githubarchive:github.timeline]
# WHERE type = 'CreateEvent'
# ORDER BY created_at DESC
# LIMIT 5
# Out:
# [{u'created_at': u'2014-08-13 07:05:24',
#   u'repository_language': None,
#   u'repository_name': u'asdwfer',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-08-13 07:05:20',
#   u'repository_language': None,
#   u'repository_name': u'Pinyes',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-08-13 07:05:18',
#   u'repository_language': None,
#   u'repository_name': u'sle2docker',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-08-13 07:05:18',
#   u'repository_language': None,
#   u'repository_name': u'aramark-status-report-app',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-08-13 07:05:15',
#   u'repository_language': None,
#   u'repository_name': u'Pinyes',
#   u'type': u'CreateEvent'}]

# %% [markdown]
# ### Finding the popular languages

# %%
# %%bq_sql popular_languages
# SELECT repository_language, COUNT(repository_language) as pushes
# FROM [githubarchive:github.timeline]
# WHERE type = 'PushEvent'
#   AND repository_language != ''
#   AND PARSE_UTC_USEC(created_at) >= DATE_ADD(CURRENT_TIMESTAMP(), -1, 'YEAR')
# GROUP BY repository_language
# ORDER BY pushes DESC
# LIMIT 25

# %% [markdown]
# Lets execute the query. Additionally, lets convert this to a standard python pandas dataframe. So BigQuery easily integrates into the python data analysis story naturally, and out-of-the-box.

# %%
popular_languages.results().to_dataframe()
# Out:
#      pushes repository_language
# 0   9469191          JavaScript
# 1   6463233                Java
# 2   4993682              Python
# 3   4524881                 CSS
# 4   4167769                 PHP
# 5   4115038                Ruby
# 6   2932236                 C++
# 7   2509615                   C
# 8   1706295               Shell
# 9   1331554                  C#
# 10   875257         Objective-C
# 11   461512                VimL
# 12   441253                Perl
# 13   429171                  Go
# 14   352431                   R
# 15   346563        CoffeeScript
# 16   344517               Scala
# 17   310044                 TeX
# 18   234373                 Lua
# 19   224459             Haskell
# 20   214838          Emacs Lisp
# 21   163155             Clojure
# 22   142753              Matlab
# 23   137978              Puppet
# 24   124993              Groovy

# %% [markdown]
# Lets do a join query - notice the use of `$popular_languages` - any python variable can be substituted into the SQL. In this case the variable is a query, so its SQL representation gets used.
#
# This query will return pushes per user per language, again over the course of the last year, for just the popular languages.
#
# Again, we're just defining the query, not yet executing it.

# %% [markdown]
# ### Finding the push events
# Only for the popular languages... otherwise there are too many languages just adding noise.

# %%
# %%bq_sql pushes
# SELECT timeline.actor AS user, timeline.repository_language AS language, COUNT(timeline.repository_language) AS pushes
# FROM [githubarchive:github.timeline] AS timeline
# JOIN $popular_languages AS languages
#   ON timeline.repository_language = languages.repository_language
# WHERE type = 'PushEvent'
#   AND PARSE_UTC_USEC(created_at) >=
#       DATE_ADD(CURRENT_TIMESTAMP(), -1, 'YEAR')
# GROUP BY user, language

# %% [markdown]
# Lets nest that query into another SQL query that adds hashing to perform a sampling ... we'll take a 5% sample.

# %%
# %%bq_sql sampled_pushes
# SELECT user, language, pushes
# FROM $pushes
# WHERE ABS(HASH(user)) % 100 < 5

# %% [markdown]
# And then execute the query, again converting the result-set into a dataframe. Lets also see the length, and a few rows of data to get a sense of what we have to work with.

# %%
df = sampled_pushes.results().to_dataframe()
len(df)
# Out:
# 101197

# %%
df[:10]
# Out:
#      language  pushes               user
# 0       Shell      21       stevelorimer
# 1         C++    1147         bytemaster
# 2      Python       9        akshayn1107
# 3  JavaScript     560              pilsy
# 4      Python      94  DanielGandarillas
# 5  JavaScript      38         SyncShinee
# 6          C#     502          peteroupc
# 7        Ruby      84            payam10
# 8          Go       1          wendellou
# 9         PHP      90             Thynix

# %% [markdown]
# ## Data Analysis in Python

# %% [markdown]
# The results we have so far, have multiple rows for each user. One per language. Pivot that data, so we have one row per user, and one column per language.
#
# Pandas offers a built-in `pivot()` method.

# %%
dfp = df.pivot(index = 'user', columns = 'language', values = 'pushes') \
        .fillna(0)
dfp
# Out:
# language            C  C#  C++  CSS  Clojure  CoffeeScript  Emacs Lisp  Go  \
# user
# 000014h             0   0    0    0        0             0           0   0
# 0003                0   0    0    0        0             0           0   0
# 0065paula           0   0    0    9        0             0           0   0
# 008agent            5  15    2    0        0             0           0   0
# 00StevenG           0   0    0    0        0             0           0   0
# 00wuyu00            0   0    0    0        0             0           0   0
# 0102                0   0    0    0        0             0           0   0
# 0110              255   0    0    0        0             0           0   0
# 01d55               0   0    1    0        0             0           0   0
# 01es                0   0    0    0        0             0           0   0
# 01esha              0   0    0    0        0             0           0   0
# 01gaunte            0   0    0    0        0             0           0   0
# 02110917            0   0    0    0        0             0           0   0
# 0325189             0   0    0    0        0             0           0   0
# 03731               1   0    0    0        0             0           0   0
# 03knoppg            0   5    0    0        0             0           0   0
# 03lafaye            0   0    0    0        0             0           0   0
# 040378c0            0   0    0    0        0             0           0   0
# 0486zhc             0   0    0    0        0             0           0   0
# 051                 0   0    0    0        0             0           0   0
# 0532yangyang        0   0    0    0        0             0           0   0
# 05K4R               0   0    0    0        0             0           0   0
# 05lindne            0   0    1    0        0             0           0   0
# 0607chris           0   0    0    0        0             0           0   0
# 0612800232          0   0    0    0        0             0           0   0
# 061375              0   0    0    0        0             0           0   0
# 06peng              0   0    0    0        0             0           0   0
# 0878685             0   0    0    0        0             0           0   0
# 09liweis            0   0    0    3        0             0           0   0
# 0VAN                0   0    0    0        0             0           0   0
# ...               ...  ..  ...  ...      ...           ...         ...  ..
# zyla                0   0    1    0        0             0           0   0
# zym1010             0   0    0    0        0             0           0   0
# zymen               0   0    0    0        0             0           0   0
# zymiroe             0   0    0    0        0             0           0   0
# zymphad            80   0   12    0        0             0           0   0
# zyn0401             0   1    0    0        0             0           0   0
# zyndok              0   0    0    0        0             0           0   0
# zynne               0   0    0    0        0             0           0   0
# zytal               0   0    0    0        0             0           0   0
# zyuce               0   0    0    0        0             0           0   0
# zyxawl              0   0    0    0        0             0           0   0
# zyxlive             0   0    0    0        0             0           0   0
# zyzlik              0   0    0    1        0             0           0   0
# zzaewon             0   0    0    0        0             0           0   0
# zzambushzz          0   0    0    2        0             0           0   0
# zzapal              0   0    0    0        0             0           0   0
# zzcworld            2   0    0    0        0             0           0   0
# zzh1989829          0   0   12    1        0             0           0   0
# zzh2005             0   0    0    0        0             0           0   0
# zzhou               0   0    0    0        0             0           0   0
# zzimdak             0   0    0    0        0             0           0   0
# zzltjnh             1   0    0    3        0             0           0   0
# zzongaly            0   0    4    0        0             0           0   0
# zzorn              10   0    0    0        0             0           0   0
# zzs213              0   0    0    0        0             0           0   0
# zzxwill             0   0    0    0        0             0           0   0
# zzzili              0   0    0    0        0             0           0   0
# zzzjojo1            0   0    0    0        0             0           0   0
# zzzzzzzzzzzzz       0   0    0    0        0             0           0   0
# zzzzzzzzzzzzzzzz    0   0    0    1        0             0           0   0
#
# language          Groovy  Haskell   ...     PHP  Perl  Puppet  Python  R  \
# user                                ...
# 000014h                0        0   ...       0     0       0       0  0
# 0003                   0        0   ...       0     0       0       8  0
# 0065paula              0        0   ...       0     0       0      23  0
# 008agent               0        0   ...       0     0       0       0  0
# 00StevenG              0        0   ...       0     0       0       0  0
# 00wuyu00               0        0   ...       0     0       0       4  0
# 0102                   0        0   ...       0     0       0       0  0
# 0110                   0        0   ...       0     0       0       2  0
# 01d55                  0        0   ...       0     0       0       0  0
# 01es                   0        0   ...       0     0       0       0  0
# 01esha                 0        0   ...       0     0       0       1  0
# 01gaunte               0        0   ...       0     0       0       1  0
# 02110917               0        0   ...       0     0       0       0  0
# 0325189                0        0   ...       0     0       0       0  0
# 03731                  0        0   ...       0     0       0       0  0
# 03knoppg               0        0   ...       0     0       0       0  0
# 03lafaye               0        0   ...       0     0       0       3  0
# 040378c0               0        0   ...       0     0       0       1  0
# 0486zhc                0        0   ...       0     0       0       0  0
# 051                    0        0   ...       0     0       0       0  0
# 0532yangyang           0        0   ...       0     0       0       0  0
# 05K4R                  0        0   ...       0     0       0       0  0
# 05lindne               0        0   ...       0     0       0       0  0
# 0607chris              0        0   ...       0     0       0       0  0
# 0612800232             0        0   ...       0     0       0       0  0
# 061375                 0        0   ...       2     0       0       0  0
# 06peng                 0        0   ...       0     0       0       0  0
# 0878685                0        0   ...       0     0       0       1  0
# 09liweis               0        0   ...       0     0       0       0  0
# 0VAN                   0        0   ...       0     0       0      44  0
# ...                  ...      ...   ...     ...   ...     ...     ... ..
# zyla                   0        0   ...       0     0       0       0  0
# zym1010                0        0   ...       0     0       0       0  4
# zymen                  0        0   ...       0     0       0      13  0
# zymiroe                0        0   ...       0     0       0       0  0
# zymphad                0        0   ...       0     0       0       0  0
# zyn0401                0        0   ...       0     0       0       0  0
# zyndok                 0        0   ...       0     0       0       0  0
# zynne                  0        0   ...       0     0       0       0  0
# zytal                  0        0   ...       0     0       0       0  0
# zyuce                  0        0   ...       0     0       0       0  0
# zyxawl                 0        0   ...       0     0       0       2  0
# zyxlive                0        0   ...       0     0       0       0  0
# zyzlik                 0        0   ...       0     0       0       0  0
# zzaewon                0        0   ...       0     0       0       0  0
# zzambushzz             0        0   ...       0     0       0       0  0
# zzapal                 0        0   ...       0     0       0       0  0
# zzcworld               0        0   ...       0     0       0       0  0
# zzh1989829             0        0   ...       0     0       0       0  0
# zzh2005                0        0   ...       0     0       0       0  0
# zzhou                  0        0   ...       0     0       0       9  0
# zzimdak                0        0   ...       0     0       0       0  0
# zzltjnh                0        0   ...       0     0       0       0  0
# zzongaly               0        0   ...       0     0       0       0  0
# zzorn                  2        0   ...       0     0       0       0  0
# zzs213                 0        0   ...       0     0       0       0  0
# zzxwill                0        0   ...       0     0       0       0  0
# zzzili                 0        0   ...       0     0       0       0  0
# zzzjojo1               0        0   ...       0     0       0       0  0
# zzzzzzzzzzzzz          0        0   ...       0     0       0       0  0
# zzzzzzzzzzzzzzzz       0        0   ...       0     0       0       0  0
#
# language          Ruby  Scala  Shell  TeX  VimL
# user
# 000014h              0      0      0    0     0
# 0003                 0      0      0    0     0
# 0065paula            0      0      0    0     0
# 008agent             0      0      0    0     0
# 00StevenG            0      0      0    0     0
# 00wuyu00             0      0      0    0     0
# 0102                 0      0      0    0     6
# 0110                 0      0      0    0     0
# 01d55                0      0      0    0     0
# 01es                 0      2      3    0     0
# 01esha               0      0      0    0     0
# 01gaunte             0      0      0    0     0
# 02110917             0      0      0    0     0
# 0325189              0      0      0    0     0
# 03731                0      0      0    0     0
# 03knoppg             0      0      0    0     0
# 03lafaye             1      0      0    0     0
# 040378c0             0      0      0    0     0
# 0486zhc              0      0      0    0     0
# 051                  0      0      0    0     0
# 0532yangyang         0      0      0    0     0
# 05K4R                0      0      0    0     0
# 05lindne             0      0      0    0     0
# 0607chris            0      0      0    0     0
# 0612800232           1      0      0    0     0
# 061375               0      0      0    0     0
# 06peng               0      0      4    0     0
# 0878685              0      0      0    0     0
# 09liweis             2      0      0    0     0
# 0VAN                 0      0      0    0     0
# ...                ...    ...    ...  ...   ...
# zyla                 0      0      0    0     0
# zym1010              0      0      0   14     0
# zymen                0      0      0    0     9
# zymiroe              0      0      0    0     0
# zymphad              0      0      3    0     0
# zyn0401              0      0      0    0     0
# zyndok               3      0      0    0     0
# zynne                0      0      0    0     0
# zytal                0      0      0    0     0
# zyuce                0      0      0    0     0
# zyxawl               0      0      0    0     0
# zyxlive              0      0      0    0     0
# zyzlik               0      0      0    0     0
# zzaewon              0      0      0    0     0
# zzambushzz           0      0      0    0     0
# zzapal               0      0      0    0     0
# zzcworld             0      0      0    0     0
# zzh1989829           0      0      0    0     0
# zzh2005              0      0      0    0     0
# zzhou                0      0      0    0     0
# zzimdak              0      0      0    0     0
# zzltjnh              0      0      0    0     0
# zzongaly             0      0      0    0     0
# zzorn                0      4     32    0     0
# zzs213               0      0      0    0     3
# zzxwill              0      0      0    0     0
# zzzili               0      0      0    0     0
# zzzjojo1             0      0      0    0     0
# zzzzzzzzzzzzz       17      0      0    0     0
# zzzzzzzzzzzzzzzz     0      0      0    0     0
#
# [56885 rows x 25 columns]

# %% [markdown]
# And then compute the correlation for each pair of columns, again, built-in into the pandas library.

# %%
corr = dfp.corr(method = 'spearman')
corr
# Out:
# language             C        C#       C++       CSS   Clojure  CoffeeScript  \
# language
# C             1.000000 -0.009410  0.214398 -0.029522  0.009789      0.013076
# C#           -0.009410  1.000000  0.011097 -0.044945 -0.004918      0.005835
# C++           0.214398  0.011097  1.000000 -0.050427  0.003958      0.004799
# CSS          -0.029522 -0.044945 -0.050427  1.000000  0.043751      0.091475
# Clojure       0.009789 -0.004918  0.003958  0.043751  1.000000      0.037326
# CoffeeScript  0.013076  0.005835  0.004799  0.091475  0.037326      1.000000
# Emacs Lisp    0.037167 -0.015717  0.030220  0.022221  0.157047      0.014294
# Go            0.035670 -0.011217  0.014474  0.041054  0.048346      0.045361
# Groovy       -0.006886 -0.007621 -0.015950  0.005419  0.006704      0.007157
# Haskell       0.042645 -0.005309  0.027629  0.013070  0.053465      0.035279
# Java         -0.027669 -0.049243 -0.037068 -0.070037  0.008005     -0.021915
# JavaScript   -0.043358 -0.004260 -0.061015  0.236399  0.038827      0.139703
# Lua           0.050644  0.016999  0.039621 -0.000395  0.002073      0.002587
# Matlab        0.021977 -0.004020  0.029343 -0.011825  0.001760     -0.002977
# Objective-C   0.024295 -0.011752  0.001162 -0.019338  0.005098      0.015298
# PHP          -0.052636 -0.054885 -0.065953  0.068712 -0.015982      0.004121
# Perl          0.065375 -0.014768  0.024655  0.023440  0.016700      0.019867
# Puppet        0.013571 -0.009718 -0.008698  0.019715  0.030977      0.017109
# Python        0.077129 -0.047304  0.062139  0.037908  0.025474      0.039650
# R            -0.028158 -0.035150 -0.036153 -0.044018 -0.004462     -0.014476
# Ruby         -0.014696 -0.053086 -0.050965  0.102101  0.052230      0.095919
# Scala         0.000444 -0.012266 -0.009135  0.004984  0.020316      0.018291
# Shell         0.122316 -0.027191  0.052014  0.068311  0.056584      0.087784
# TeX           0.059359 -0.010082  0.054881  0.011287  0.014943      0.003828
# VimL          0.042512 -0.024594  0.028296  0.062434  0.050111      0.079686
#
# language      Emacs Lisp        Go    Groovy   Haskell    ...          PHP  \
# language                                                  ...
# C               0.037167  0.035670 -0.006886  0.042645    ...    -0.052636
# C#             -0.015717 -0.011217 -0.007621 -0.005309    ...    -0.054885
# C++             0.030220  0.014474 -0.015950  0.027629    ...    -0.065953
# CSS             0.022221  0.041054  0.005419  0.013070    ...     0.068712
# Clojure         0.157047  0.048346  0.006704  0.053465    ...    -0.015982
# CoffeeScript    0.014294  0.045361  0.007157  0.035279    ...     0.004121
# Emacs Lisp      1.000000  0.053517 -0.002732  0.072452    ...    -0.016636
# Go              0.053517  1.000000  0.004929  0.025558    ...    -0.007720
# Groovy         -0.002732  0.004929  1.000000  0.008158    ...    -0.023299
# Haskell         0.072452  0.025558  0.008158  1.000000    ...    -0.019293
# Java           -0.016175 -0.012233  0.089168 -0.004588    ...    -0.109912
# JavaScript      0.009393  0.032514 -0.000508  0.017903    ...     0.038386
# Lua             0.020940  0.023807  0.000975  0.013756    ...    -0.006568
# Matlab          0.006107 -0.005801 -0.007737  0.013799    ...    -0.025107
# Objective-C     0.002339  0.009306 -0.005515 -0.006456    ...    -0.041245
# PHP            -0.016636 -0.007720 -0.023299 -0.019293    ...     1.000000
# Perl            0.032729  0.024647 -0.002664  0.028458    ...     0.006892
# Puppet          0.020344  0.031189  0.016302  0.003748    ...     0.028403
# Python          0.043111  0.061735 -0.004515  0.041280    ...    -0.055202
# R              -0.004333 -0.012745 -0.008059  0.000209    ...    -0.053756
# Ruby            0.036788  0.062580 -0.001564  0.018585    ...    -0.048526
# Scala           0.019163  0.040931  0.032441  0.054555    ...    -0.026145
# Shell           0.089842  0.094253  0.045266  0.055143    ...     0.013496
# TeX             0.026409  0.015154 -0.000216  0.060511    ...    -0.023811
# VimL            0.032814  0.073079 -0.002095  0.059027    ...     0.002625
#
# language          Perl    Puppet    Python         R      Ruby     Scala  \
# language
# C             0.065375  0.013571  0.077129 -0.028158 -0.014696  0.000444
# C#           -0.014768 -0.009718 -0.047304 -0.035150 -0.053086 -0.012266
# C++           0.024655 -0.008698  0.062139 -0.036153 -0.050965 -0.009135
# CSS           0.023440  0.019715  0.037908 -0.044018  0.102101  0.004984
# Clojure       0.016700  0.030977  0.025474 -0.004462  0.052230  0.020316
# CoffeeScript  0.019867  0.017109  0.039650 -0.014476  0.095919  0.018291
# Emacs Lisp    0.032729  0.020344  0.043111 -0.004333  0.036788  0.019163
# Go            0.024647  0.031189  0.061735 -0.012745  0.062580  0.040931
# Groovy       -0.002664  0.016302 -0.004515 -0.008059 -0.001564  0.032441
# Haskell       0.028458  0.003748  0.041280  0.000209  0.018585  0.054555
# Java         -0.018559 -0.010344 -0.064413 -0.063425 -0.100281  0.044104
# JavaScript    0.013177  0.020832  0.016266 -0.065390  0.072940  0.014009
# Lua           0.019106  0.008377  0.026454 -0.009358  0.005907  0.002167
# Matlab       -0.001934 -0.004037  0.033383  0.024160 -0.022790  0.013353
# Objective-C   0.000216 -0.009296 -0.025895 -0.028176  0.019789 -0.010744
# PHP           0.006892  0.028403 -0.055202 -0.053756 -0.048526 -0.026145
# Perl          1.000000  0.040141  0.053953  0.000701  0.023672  0.009147
# Puppet        0.040141  1.000000  0.038096 -0.012464  0.088625  0.006312
# Python        0.053953  0.038096  1.000000 -0.022298 -0.013330  0.013522
# R             0.000701 -0.012464 -0.022298  1.000000 -0.046977  0.003254
# Ruby          0.023672  0.088625 -0.013330 -0.046977  1.000000  0.002311
# Scala         0.009147  0.006312  0.013522  0.003254  0.002311  1.000000
# Shell         0.100030  0.098550  0.127179 -0.020986  0.098057  0.050094
# TeX           0.033984 -0.000689  0.077672  0.035939 -0.003141  0.013571
# VimL          0.070908  0.047316  0.082532 -0.016153  0.096722  0.021314
#
# language         Shell       TeX      VimL
# language
# C             0.122316  0.059359  0.042512
# C#           -0.027191 -0.010082 -0.024594
# C++           0.052014  0.054881  0.028296
# CSS           0.068311  0.011287  0.062434
# Clojure       0.056584  0.014943  0.050111
# CoffeeScript  0.087784  0.003828  0.079686
# Emacs Lisp    0.089842  0.026409  0.032814
# Go            0.094253  0.015154  0.073079
# Groovy        0.045266 -0.000216 -0.002095
# Haskell       0.055143  0.060511  0.059027
# Java          0.000538  0.002903 -0.042032
# JavaScript    0.064590 -0.008573  0.057582
# Lua           0.047517  0.015755  0.039934
# Matlab       -0.000651  0.054999 -0.003390
# Objective-C   0.001007 -0.003423  0.005884
# PHP           0.013496 -0.023811  0.002625
# Perl          0.100030  0.033984  0.070908
# Puppet        0.098550 -0.000689  0.047316
# Python        0.127179  0.077672  0.082532
# R            -0.020986  0.035939 -0.016153
# Ruby          0.098057 -0.003141  0.096722
# Scala         0.050094  0.013571  0.021314
# Shell         1.000000  0.047569  0.188028
# TeX           0.047569  1.000000  0.027422
# VimL          0.188028  0.027422  1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# ## Data Visualization
#
# All those numbers are great, but seeing a plot will make the data speak a lot louder. Red for least correlated, and blue for the most.
#
# The visualization is done using matplotlib, which is the defacto library used in ipython notebooks.
#
# **Future note**: we're going to look into building a more purpose/scenario-driven visualization library based on d3.js (think interactive visualization) that is language agnostic.

# %%
def plot_correlation(data, title = '', type = ''):
    min_value = 0
    max_value = 0

    for i in range(len(data.columns)):
        for j in range(len(data.columns)):
            if i != j:
                min_value = min(min_value, data.iloc[i, j])
                max_value = max(max_value, data.iloc[i, j])
    span = max(abs(min_value), abs(max_value))
    span = round(span + .05, 1)

    items = data.columns.tolist()
    ticks = np.arange(0.5, len(items) + 0.5)

    plot.figure(figsize = (11, 7))
    plot.pcolor(data.values, cmap = 'RdBu', vmin = -span, vmax = span)
    plot.colorbar().set_label(type)
    plot.title(title)
    plot.xticks(ticks, items, rotation = 'vertical')
    plot.yticks(ticks, items)
    plot.show()

# %%
plot_correlation(corr, 'Language Correlation', 'Spearman Correlation')
