# %% [markdown]
# # Charting - Interactive Charts
#
# This notebook demonstrates how you can use the %chart magic to quickly chart data in BigQuery tables, and other sources such as Python lists.
#
# This notebook uses several data sets to examine how to quickly draw different style charts.
#
#
# Related Links:
#
# * [BigQuery](https://cloud.google.com/bigquery/)
# * BigQuery [SQL reference](https://cloud.google.com/bigquery/query-reference)
# * [Google Charts](https://developers.google.com/chart/)

# %%
import gcp.bigquery as bq

# %% [markdown]
# All the chart magics take a data source argument, which can be a table name, or a reference to a table, query or view.
#
# The magic uses Google Charts to easily chart data without having to write code. The first argument is the type of chart we want, and as you can see from the help below, numerous types are supported:

# %%
# %chart --help
# Out:
# usage: %%chart [-h]
#                {annotation,area,bars,bubbles,calendar,candlestick,columns,combo,gauge,geo,histogram,line,map,org,paged_table,pie,sankey,scatter,stepped_area,table,timeline,treemap}
#                ...
#
# Generate an inline chart using Google Charts using the data in a Table, Query,
# dataframe, or list. Numerous types of charts are supported. Options for the
# charts can be specified in the cell body using YAML or JSON.
#
# positional arguments:
#   {annotation,area,bars,bubbles,calendar,candlestick,columns,combo,gauge,geo,histogram,line,map,org,paged_table,pie,sankey,scatter,stepped_area,table,timeline,treemap}
#                         commands
#     annotation          Generate a annotation chart.
#     area                Generate a area chart.
#     bars                Generate a bars chart.
#     bubbles             Generate a bubbles chart.
#     calendar            Generate a calendar chart.
#     candlestick         Generate a candlestick chart.
#     columns             Generate a columns chart.
#     combo               Generate a combo chart.
#     gauge               Generate a gauge chart.
#     geo                 Generate a geo chart.
#     histogram           Generate a histogram chart.
#     line                Generate a line chart.
#     map                 Generate a map chart.
#     org                 Generate a org chart.
#     paged_table         Generate a paged_table chart.
#     pie                 Generate a pie chart.
#     sankey              Generate a sankey chart.
#     scatter             Generate a scatter chart.
#     stepped_area        Generate a stepped_area chart.
#     table               Generate a table chart.
#     timeline            Generate a timeline chart.
#     treemap             Generate a treemap chart.
#
# optional arguments:
#   -h, --help            show this help message and exit

# %% [markdown]
# Following the chart type, we can specify the data to be charted. However, Google Charts requires columns in data to be in a specific order so we are often going to need to specify these as well, unless our data happens to be in the order we want. We can do this with the --field parameter which takes a comma-separated list of fields. Finally, the body of the cell can include additional options to be passed to the chart; these are chart-specific.

# %% [markdown]
# For our first example, lets look at the popularity of programming languages. We can use the public github_timeline data for this. First we should look at the data which we can do with a paged_table chart magic (there is also a table chart magic which will show the entire table; use that with caution with tables you know to be small only):

# %%
# %chart paged_table publicdata:samples.github_timeline
# Out:
#     <div class="bqgc" id="1_144356741276">
#     </div>
#     <script>
#       require(['extensions/charting', 'element!1_144356741276', 'style!/static/extensions/charting.css'],
#         function(charts, dom) {
#           charts.render(dom, {chartStyle:'paged_table', dataName:'0', fields:'*'}, {}, {"rows": [{"c": [{"v": "https://github.com/addyosmani/basket.js"}, {"v": true}, {"v": "2012-02-29 22:16:56"}, {"v": true}, {"v": "A proof-of-concept script loader for caching/loading scripts with localStorage"}, {"v": 15}, {"v": "false"}, {"v": true}, {"v": "http://addyosmani.github.com/basket.js"}, {"v": 192}, {"v": "false"}, {"v": "basket.js"}, {"v": "addyosmani"}, {"v": 6}, {"v": 224}, {"v": "2012-03-26 22:43:47"}, {"v": "JavaScript"}, {"v": null}, {"v": null}, {"v": null}, {"v": "0d4c856d67a55b4b65d596f0d65c3dcd"}, {"v": "User"}, {"v": "jacobbubu"}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": "2012-04-18 14:05:46"}, {"v": true}, {"v": "jacobbubu"}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": "started"}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": "https://github.com/addyosmani/basket.js"}, {"v": "WatchEvent"}]}, {"c": [{"v": "https://github.com/twall/jna"}, {"v": true}, {"v": "2011-04-29 13:30:29"}, {"v": true}, {"v": "Java Native Access"}, {"v": 48}, {"v": "false"}, {"v": true}, {"v": "http://jna.java.net"}, {"v": 3915}, {"v": "false"}, {"v": "jna"}, {"v": "twall"}, {"v": 19}, {"v": 343}, {"v": "2012-04-12 16:19:40"}, {"v": "Java"}, {"v": null}, {"v": null}, {"v": null}, {"v": "0d384b9bec39121243a0a5cc60d16f2a"}, {"v": "User"}, {"v": "sergeybe"}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": "2012-04-18 14:05:45"}, {"v": true}, {"v": "sergeybe"}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {"v": null}, {" ...

# %% [markdown]
# We will get a rough view by counting the incidences of pushes bucketed by the repository_language field. Unlike in our other notebook where we explored github data, we won't limit the set of language in the query, but will instead use the sliceVisibilityThreshold option to the pie chart to bucket all languages with less than 6 degree pie slices (i.e. less than 1/60th of the pushes) into an 'Other' bucket. Chart options are specified in the %%chart cell boduy and can be expressed in JSON or YAML. We will use JSON in this chart but YAML in the remaining examples.
#
# Note in the example below our SELECT statement returns the fields in the order we want them so we don't really need the --field argument but we include it for illustrative purposes. Also note that we can use variable replacement in the options.

# %%
# %%sql --module github_events
# SELECT repository_language, COUNT(repository_language) as pushes
# FROM [publicdata:samples.github_timeline]
# WHERE type = 'PushEvent'
#   AND repository_language != ''
# GROUP BY repository_language
# ORDER BY pushes DESC

# %%
slice_threshold = 6 / 360

# %%
# %%chart pie --field repository_language,pushes github_events
# {
#   "title": "Language Popularity",
#   "sliceVisibilityThreshold": "$slice_threshold"
# }
# Out:
#     <div class="bqgc" id="2_144356741497">
#     </div>
#     <script>
#       require(['extensions/charting', 'element!2_144356741497', 'style!/static/extensions/charting.css'],
#         function(charts, dom) {
#           charts.render(dom, {chartStyle:'pie', dataName:'1', fields:'repository_language,pushes'}, {"sliceVisibilityThreshold": "slice_threshold", "title": "Language Popularity"}, {"rows": [{"c": [{"v": "JavaScript"}, {"v": 455158}]}, {"c": [{"v": "Java"}, {"v": 341750}]}, {"c": [{"v": "Ruby"}, {"v": 324837}]}, {"c": [{"v": "Python"}, {"v": 261187}]}, {"c": [{"v": "PHP"}, {"v": 246018}]}, {"c": [{"v": "C++"}, {"v": 163494}]}, {"c": [{"v": "C"}, {"v": 161677}]}, {"c": [{"v": "Shell"}, {"v": 75076}]}, {"c": [{"v": "C#"}, {"v": 60039}]}, {"c": [{"v": "Objective-C"}, {"v": 45619}]}, {"c": [{"v": "VimL"}, {"v": 41959}]}, {"c": [{"v": "Perl"}, {"v": 36578}]}, {"c": [{"v": "Scala"}, {"v": 20502}]}, {"c": [{"v": "Emacs Lisp"}, {"v": 16672}]}, {"c": [{"v": "CoffeeScript"}, {"v": 16164}]}, {"c": [{"v": "Haskell"}, {"v": 16063}]}, {"c": [{"v": "Clojure"}, {"v
c": [{"v": "Turing"}, {"v": 90}]}, {"c": [{"v": "Boo"}, {"v": 89}]}, {"c": [{"v": "Nimrod"}, {"v": 80}]}, {"c": [{"v": "Ioke"}, {"v": 76}]}, {"c": [{"v": "Fancy"}, {"v": 71}]}, {"c": [{"v": "Arc"}, {"v": 64}]}, {"c": [{"v": "Max/MSP"}, {"v": 63}]}, {"c": [{"v": "Gosu"}, {"v": 62}]}, {"c": [{"v": "Opa"}, {"v": 61}]}, {"c": [{"v": "Rebol"}, {"v": 44}]}, {"c": [{"v": "Logtalk"}, {"v": 21}]}, {"c": [{"v": "Bro"}, {"v": 14}]}, {"c": [{"v": "Augeas"}, {"v": 10}]}, {"c": [{"v": "Mirah"}, {"v": 9}]}, {"c": [{"v": "Fantom"}, {"v": 9}]}, {"c": [{"v": "Self"}, {"v": 7}]}, {"c": [{"v": "DCPU-16 Assembly"}, {"v": 2}]}, {"c": [{"v": "Nu"}, {"v": 1}]}], "cols": [{"type": "string", "id": "repository_language", "label": "repository_language"}, {"type": "number", "id": "pushes", "label": "pushes"}]});
#         }
#       );
#     </script>

# %% [markdown]
# For a third example, let's look at weather data. The gsod sample data has weather measurements from many stations around the world. We will look at weather station 471270, which is in South Korea, from 2000 to 2010. In this example we will show that we can chart Python data, not just BigQuery tables and query results. For this station only max_temperature was measured, not min_temperature.

# %%
# %%sql --module skweather
# SELECT year, month, day, max_temperature
# FROM [publicdata:samples.gsod]
# WHERE station_number = 471270 AND year > 2000

# %% [markdown]
# We need to change the separate day, month and year fields into a single datetime
# to plot the temperature over time. To do this we will read the data into a Python data structure and then use that for the chart. We will use an annotation chart, which is useful for time series:

# %%
import time
import datetime
weather = [{'date': datetime.datetime(year=row['year'], month=row['month'], day=row['day']), 
            'max': row['max_temperature']} for row in bq.Query(skweather).results()]

# %%
# %chart annotation --field date,max weather
# Out:
#     <div class="bqgc" id="3_144356742093">
#     </div>
#     <script>
#       require(['extensions/charting', 'element!3_144356742093', 'style!/static/extensions/charting.css'],
#         function(charts, dom) {
#           charts.render(dom, {chartStyle:'annotation', dataName:'2', fields:'date,max'}, {}, {"rows": [{"c": [{"v": "2001-06-20T00:00:00"}, {"v": 64.4000015258789}]}, {"c": [{"v": "2004-07-21T00:00:00"}, {"v": 75.19999694824219}]}, {"c": [{"v": "2007-02-25T00:00:00"}, {"v": 28.600000381469727}]}, {"c": [{"v": "2009-03-30T00:00:00"}, {"v": 36.29999923706055}]}, {"c": [{"v": "2005-02-28T00:00:00"}, {"v": 19.399999618530273}]}, {"c": [{"v": "2009-05-10T00:00:00"}, {"v": 47.099998474121094}]}, {"c": [{"v": "2006-01-20T00:00:00"}, {"v": 24.100000381469727}]}, {"c": [{"v": "2004-01-28T00:00:00"}, {"v": 14.199999809265137}]}, {"c": [{"v": "2008-10-01T00:00:00"}, {"v": 48.70000076293945}]}, {"c": [{"v": "2004-04-08T00:00:00"}, {"v": 31.100000381469727}]}, {"c": [{"v": "2004-03-04T00:00:00"}, {"v": 19.0}]}, {"c": [{"v": "2003-08-22T00:00:00"}, {"v": 73.9000015258789}]}, {"c": [{"v": "2004-02-08T00:00:00"}, {"v": 17.600000381469727
:00"}, {"v": 40.79999923706055}]}, {"c": [{"v": "2007-11-17T00:00:00"}, {"v": 24.600000381469727}]}, {"c": [{"v": "2007-12-24T00:00:00"}, {"v": 23.899999618530273}]}, {"c": [{"v": "2006-11-15T00:00:00"}, {"v": 26.799999237060547}]}, {"c": [{"v": "2006-12-27T00:00:00"}, {"v": 19.899999618530273}]}, {"c": [{"v": "2009-09-14T00:00:00"}, {"v": 54.70000076293945}]}, {"c": [{"v": "2006-09-01T00:00:00"}, {"v": 64.5999984741211}]}, {"c": [{"v": "2005-10-03T00:00:00"}, {"v": 53.79999923706055}]}, {"c": [{"v": "2002-08-31T00:00:00"}, {"v": 67.5}]}, {"c": [{"v": "2008-06-07T00:00:00"}, {"v": 59.0}]}, {"c": [{"v": "2004-12-06T00:0 ...

# %% [markdown]
# For our last example, let's look at a scatter plot. This time we will look at the public natality data and plot a sample of the data, showing gestation weeks vs birth weight. We'll add some axes titles, a title and a trend line via chart options.

# %%
# %%sql --module babies
# SELECT gestation_weeks, weight_pounds FROM [publicdata:samples.natality] WHERE gestation_weeks < 99 LIMIT 1000

# %%
# %%chart scatter babies
# title: Birth Weight vs Gestation Weeks
# hAxis:
#   title: Gestation Weeks
# vAxis:
#   title: Weight
# legend: none
# trendlines:
#   0: {}
# Out:
#     <div class="bqgc" id="4_144356742137">
#     </div>
#     <script>
#       require(['extensions/charting', 'element!4_144356742137', 'style!/static/extensions/charting.css'],
#         function(charts, dom) {
#           charts.render(dom, {chartStyle:'scatter', dataName:'3', fields:'*'}, {"vAxis": {"title": "Weight"}, "trendlines": {"0": {}}, "legend": "none", "hAxis": {"title": "Gestation Weeks"}, "title": "Birth Weight vs Gestation Weeks"}, {"rows": [{"c": [{"v": 39}, {"v": 6.87621795178}]}, {"c": [{"v": 43}, {"v": 6.6248909731}]}, {"c": [{"v": 33}, {"v": 5.62619692624}]}, {"c": [{"v": 40}, {"v": 6.8122838958}]}, {"c": [{"v": 38}, {"v": 6.1883756943399995}]}, {"c": [{"v": 39}, {"v": 7.87491199864}]}, {"c": [{"v": 43}, {"v": 7.62578964258}]}, {"c": [{"v": 41}, {"v": 7.3744626639}]}, {"c": [{"v": 44}, {"v": 8.000575487979999}]}, {"c": [{"v": 40}, {"v": 8.87581066812}]}, {"c": [{"v": 39}, {"v": 6.93794738514}]}, {"c": [{"v": 46}, {"v": 9.62538235892}]}, {"c": [{"v": 39}, {"v": 8.62448368944}]}, {"c": [{"v": 41}, {"v": 7.31273323054}]}, {"c": [{"v": 39}, {"v": 8.68841774542}]}, {"c": [{"v": 46}, {"v": 6.4992274837599995}]}, {"c": [{"v": 40}, {"v": 7.43839671988}]}, {"c": [{"v": 40}, {"v": 7.5618555866}]}, {"c": [{"v": 44}, {"v": 7.1870697412}]}, {"c": [{"v": 42}, {"v": 6.0627122049999995}]}, {"c": [{"v": 39}, {"v": 7.25100379718}]}, {"c": [{"v": 39}, {"v": 6.87621795178}]}, {"c": [{"v": 46}, {"v": 9.62538235892}]}, {"c": [{"v": 40}, {"v": 11.06279630716}]}, {"c": [{"v": 40}, {"v": 6.6248909731}]}, {"c": [{"v": 43}, {"v": 6.9996768185
}, {"c": [{"v": 37}, {"v": 6.4374980503999994}]}, {"c": [{"v": 41}, {"v": 7.81318256528}]}, {"c": [{"v": 38}, {"v": 8.811876612139999}]}, {"c": [{"v": 42}, {"v": 6.8122838958}]}, {"c": [{"v": 38}, {"v": 6.4992274837599995}]}, {"c": [{"v": 40}, {"v": 7.5618555866}]}, {"c": [{"v": 38}, {"v": 6.8122838958}]}, {"c": [{"v": 39}, {"v": 8.999269534 ...

# %% [markdown]
# For our next example, we will use a map, and draw the location of London's railway stations on the Bakerloo line.
# This data isn't in BigQuery; we'll just create it in the notebook. The source for this is the public domain
# station data from here: http://wiki.openstreetmap.org/wiki/List_of_London_Underground_stations

# %%
stations = [
{'name': 'Baker Street', 'latitude': 51.52265, 'longitude': -0.15704},
{'name': 'Charing Cross', 'latitude': 51.507108, 'longitude': -0.122963},
{'name': 'Edgware Road (Bakerloo Line)', 'latitude': 51.519560, 'longitude': -0.169068},
{'name': 'Elephant & Castle', 'latitude': 51.49467, 'longitude': -0.10047},
{'name': 'Embankment', 'latitude': 51.50717, 'longitude': -0.12195},
{'name': 'Harlesden', 'latitude': 51.53628278, 'longitude': -0.257622488},
{'name': 'Harrow & Wealdstone', 'latitude': 51.59205973, 'longitude': -0.334725352},
{'name': 'Kensal Green', 'latitude': 51.53060655, 'longitude': -0.224253545},
{'name': 'Kenton', 'latitude': 51.58173809, 'longitude': -0.316870809},
{'name': 'Kilburn Park', 'latitude': 51.53495818, 'longitude': -0.193963023},
{'name': 'Lambeth North', 'latitude': 51.49894, 'longitude': -0.11216},
{'name': 'Maida Vale', 'latitude': 51.52989409, 'longitude': -0.185888819},
{'name': 'Marylebone', 'latitude': 51.522660, 'longitude': -0.162996},
{'name': 'North Wembley', 'latitude': 51.56258091, 'longitude': -0.304072648},
{'name': 'Oxford Circus', 'latitude': 51.51517, 'longitude': -0.14119},
{'name': 'Paddington', 'latitude': 51.5151846554, 'longitude': -0.17553880792},
{'name': 'Piccadilly Circus', 'latitude': 51.51022, 'longitude': -0.13392},
{'name': 'Queen\'s Park', 'latitude': 51.534179, 'longitude': -0.205257721},
{'name': 'Regent\'s Park', 'latitude': 51.52344, 'longitude': -0.14713},
{'name': 'South Kenton', 'latitude': 51.57044666, 'longitude': -0.308566354},
{'name': 'Stonebridge Park', 'latitude': 51.54402388, 'longitude': -0.275978856},
{'name': 'Warwick Avenue', 'latitude': 51.52329728, 'longitude': -0.183777837},
{'name': 'Waterloo', 'latitude': 51.50322, 'longitude': -0.11328},
{'name': 'Wembley Central', 'latitude': 51.55122817, 'longitude': -0.29577538},
{'name': 'Willesden Junction', 'latitude': 51.53181, 'longitude': -0.242350}]

# %% [markdown]
# For our map we will specify the showTip option which will show the 3rd column (the station name) when hovering over a map pushpin. The useMapTypeControl option lets use switch between regular and satellite maps. We use YAML for the options this and following times.

# %%
# %%chart map --field latitude,longitude,name stations
# showTip: true
# mapType: normal
# useMapTypeControl: true
# Out:
#     <div class="bqgc" id="5_144356742299">
#     </div>
#     <script>
#       require(['extensions/charting', 'element!5_144356742299', 'style!/static/extensions/charting.css'],
#         function(charts, dom) {
#           charts.render(dom, {chartStyle:'map', dataName:'4', fields:'latitude,longitude,name'}, {"mapType": "normal", "showTip": true, "useMapTypeControl": true}, {"rows": [{"c": [{"v": 51.52265}, {"v": -0.15704}, {"v": "Baker Street"}]}, {"c": [{"v": 51.507108}, {"v": -0.122963}, {"v": "Charing Cross"}]}, {"c": [{"v": 51.51956}, {"v": -0.169068}, {"v": "Edgware Road (Bakerloo Line)"}]}, {"c": [{"v": 51.49467}, {"v": -0.10047}, {"v": "Elephant & Castle"}]}, {"c": [{"v": 51.50717}, {"v": -0.12195}, {"v": "Embankment"}]}, {"c": [{"v": 51.53628278}, {"v": -0.257622488}, {"v": "Harlesden"}]}, {"c": [{"v": 51.59205973}, {"v": -0.334725352}, {"v": "Harrow & Wealdstone"}]}, {"c": [{"v": 51.53060655}, {"v": -0.224253545}, {"v": "Kensal Green"}]}, {"c": [{"v": 51.58173809}, {"v": -0.316870809}, {"v": "Kenton"}]}, {"c": [{"v": 51.53495818}, {"v": -0.193963023}, {"v": "Kilburn Park"}]}, {"c": [{"v": 51.49894}, {"v": -0.11216}, {"v": "Lambeth North"}]}, {"c": [{"v": 51.52989409}, {"v": -0.185888819}, {"v": "Maida Vale"}]}, {"c": [{"v": 51.52266}, {"v": -0.162996}, {"v": "Marylebone"}]}, {"c": [{"v": 51.56258091}, {"v": -0.304072648}, {"v": "North Wembley"}]}, {"c": [{"v": 51.51517}, {"v": -0.14119}, {"v": "Oxford Circus"}]}, {"c": [{"v": 51.5151846554}, {"v": -0.17553880792}, {"v": "Paddington"}]}, {"c": [{"v": 51.51022}, {"v": -0.13392}, {"v": "Piccadilly Circus"}]}, {"c": [{"v": 51.534179}, {"v": -0.205257721}, {"v": "Queen's Park"}]}, {"c": [{"v": 51.52344}, {"v": -0.14713}, {"v": "Regent's Park"}]}, {"c": [{"v": 51.57044666}, {"v": -0.308566354}, {"v": "South Kenton"}]}, {"c": [{"v": 51.54402388}, {"v": -0.275978856}, {"v": "Stonebridge Park"}]}, {"c": [{"v": 51.52329728}, {"v": -0.183777837}, {"v": "Warwick Avenue"}]}, {"c": [{"v": 51.50322}, {"v": -0.11328}, {"v": "Waterloo"}]}, {"c": [{"v": 51.55122817}, {"v": -0.29577538}, {"v": "Wembley Central"}]}, {"c": [{"v": 51.53181}, {"v": -0.24235}, {"v": "Willesden Junction"}]}], "cols": [{"type": "number", "id": "latitude", "label": "latitude"}, {"type": "number", "id": "longitude", "label": "longitude"}, {"type": "string", "id": "name", "label": "name"}]});
#         }
#       );
#     </script>

# %% [markdown]
# Finally, let's look at a different type of map chart. We will use a 'geo' chart to show the number of births in different US states during the 1980s. To do this we will make use of the public natality data set. Let's first get define a query to get the data we want to plot:

# %%
# %%sql --module births
# SELECT state, COUNT(*) count_babies
# FROM [publicdata:samples.natality]
# WHERE year >= 1980 AND year < 1990
# GROUP BY state

# %% [markdown]
# Now we can draw the chart. We add some JSON options to the chart to specify we want a US map at state (province) resolution (for more options see the documentation here: https://developers.google.com/chart/interactive/docs/gallery/geochart).

# %%
# %%chart geo births
# region: US
# resolution: provinces
# Out:
#     <div class="bqgc" id="6_144356742334">
#     </div>
#     <script>
#       require(['extensions/charting', 'element!6_144356742334', 'style!/static/extensions/charting.css'],
#         function(charts, dom) {
#           charts.render(dom, {chartStyle: