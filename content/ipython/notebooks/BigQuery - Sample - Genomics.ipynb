# %% [markdown]
# # BigQuery - Sample - Genomics
#
# This notebook demonstrates working with sample gene data stored as publicly accessible BigQuery datasets.
#
# ### In this notebook you will
#
# * Explore genomics datasets available in BigQuery
#   * Personal Genome Project
#   * 1000 Genomes
# * Use the `%%bq_sql` statement to write and execute SQL statements within the notebook
# * Extract data from BigQuery and create a local dataset that can be manipulated in Python
# * Refine and pivot your local dataset via the Pandas Python library
# * Visualize different aspects of your dataset via the Matplotlib Python library
#
#
# ### Attribution
# This notebook is based on the [Google Genomics](https://cloud.google.com/genomics/) BigQuery examples here:
# * [Personal Genome Project](https://github.com/googlegenomics/bigquery-examples/tree/master/pgp)
# * [1000 Genomes](https://github.com/googlegenomics/bigquery-examples/tree/master/1000genomes/data-stories/exploring-the-phenotypic-data)
#
# ----

# %% [markdown]
# # Exploring the Personal Genome Project dataset

# %% [markdown]
# First let's look at the table of phenotypes that we want to explore here. We can use the `gcp.bigquery` Python package to fetch the table schema. We can see a number of fields that provide details for a given participant's genome, such as the existence of certain diseases/conditions (e.g., has_Asthma) as well as the participant's heritage (e.g., Maternal_grandfather_Country_of_origin).

# %%
import gcp.bigquery as bq
import gcp.interactive
phenotypes = bq.table('google.com:biggene:pgp.phenotypes')
phenotypes.schema()
# Out:
# [<gcp.bigquery._table._Field at 0x10d6d5390>,
#  <gcp.bigquery._table._Field at 0x10d6d5350>,
#  <gcp.bigquery._table._Field at 0x10d6d5310>,
#  <gcp.bigquery._table._Field at 0x10d6d52d0>,
#  <gcp.bigquery._table._Field at 0x10d6d5290>,
#  <gcp.bigquery._table._Field at 0x10d6d5250>,
#  <gcp.bigquery._table._Field at 0x10d6d5210>,
#  <gcp.bigquery._table._Field at 0x10d6d51d0>,
#  <gcp.bigquery._table._Field at 0x10d6d5b10>,
#  <gcp.bigquery._table._Field at 0x10d6d5b50>,
#  <gcp.bigquery._table._Field at 0x10d6d5b90>,
#  <gcp.bigquery._table._Field at 0x10d6d5bd0>,
#  <gcp.bigquery._table._Field at 0x10d6d5c10>,
#  <gcp.bigquery._table._Field at 0x10d6d5c50>,
#  <gcp.bigquery._table._Field at 0x10d6d5c90>,
#  <gcp.bigquery._table._Field at 0x10d6d5cd0>,
#  <gcp.bigquery._table._Field at 0x10d6d5d10>,
#  <gcp.bigquery._table._Field at 0x10d6d5d50>,
#  <gcp.bigquery._table._Field at 0x10d6d5d90>,
#  <gcp.bigquery._table._Field at 0x10d6d5dd0>,
#  <gcp.bigquery._table._Field at 0x10d6d5e10>,
#  <gcp.bigquery._table._Field at 0x10d6d5e50>,
#  <gcp.bigquery._table._Field at 0x10d6d5e90>,
#  <gcp.bigquery._table._Field at 0x10d6d5ed0>,
#  <gcp.bigquery._table._Field at 0x10d6d5f10>,
#  <gcp.bigquery._table._Field at 0x10d6d5f50>,
#  <gcp.bigquery._table._Field at 0x10d6d5f90>,
#  <gcp.bigquery._table._Field at 0x10d6d5fd0>,
#  <gcp.bigquery._table._Field at 0x10d6ed050>,
#  <gcp.bigquery._table._Field at 0x10d6ed090>,
#  <gcp.bigquery._table._Field at 0x10d6ed0d0>,
#  <gcp.bigquery._table._Field at 0x10d6ed110>,
#  <gcp.bigquery._table._Field at 0x10d6ed150>,
#  <gcp.bigquery._table._Field at 0x10d6ed190>,
#  <gcp.bigquery._table._Field at 0x10d6ed1d0>,
#  <gcp.bigquery._table._Field at 0x10d6ed210>,
#  <gcp.bigquery._table._Field at 0x10d6ed250>,
#  <gcp.bigquery._table._Field at 0x10d6ed290>,
#  <gcp.bigquery._table._Field at 0x10d6ed2d0>,
#  <gcp.bigquery._table._Field at 0x10d6ed310>,
#  <gcp.bigquery._table._Field at 0x10d6ed350>,
#  <gcp.bigquery._table._Field at 0x10d6ed390>,
#  <gcp.bigquery._table._Field at 0x10d6ed3d0>,
#  <gcp.bigquery._table._Field at 0x10d6ed410>,
#  <gcp.bigquery._table._Field at 0x10d6ed450>,
#  <gcp.bigquery._table._Field at 0x10d6ed490>,
#  <gcp.bigquery._table._Field at 0x10d6ed4d0>,
#  <gcp.bigquery._table._Field at 0x10d6ed510>,
#  <gcp.bigquery._table._Field at 0x10d6ed550>,
#  <gcp.bigquery._table._Field at 0x10d6ed590>,
#  <gcp.bigquery._table._Field at 0x10d6ed5d0>,
#  <gcp.bigquery._table._Field at 0x10d6ed610>,
#  <gcp.bigquery._table._Field at 0x10d6ed650>,
#  <gcp.bigquery._table._Field at 0x10d6ed690>,
#  <gcp.bigquery._table._Field at 0x10d6ed6d0>,
#  <gcp.bigquery._table._Field at 0x10d6ed710>,
#  <gcp.bigquery._table._Field at 0x10d6ed750>,
#  <gcp.bigquery._table._Field at 0x10d6ed790>,
#  <gcp.bigquery._table._Field at 0x10d6ed7d0>,
#  <gcp.bigquery._table._Field at 0x10d6ed810>,
#  <gcp.bigquery._table._Field at 0x10d6ed850>,
#  <gcp.bigquery._table._Field at 0x10d6ed890>,
#  <gcp.bigquery._table._Field at 0x10d6ed8d0>,
#  <gcp.bigquery._table._Field at 0x10d6ed910>,
#  <gcp.bigquery._table._Field at 0x10d6ed950>,
#  <gcp.bigquery._table._Field at 0x10d6ed990>,
#  <gcp.bigquery._table._Field at 0x10d6ed9d0>,
#  <gcp.bigquery._table._Field at 0x10d6eda10>,
#  <gcp.bigquery._table._Field at 0x10d6eda50>,
#  <gcp.bigquery._table._Field at 0x10d6eda90>,
#  <gcp.bigquery._table._Field at 0x10d6edad0>,
#  <gcp.bigquery._table._Field at 0x10d6edb10>,
#  <gcp.bigquery._table._Field at 0x10d6edb50>,
#  <gcp.bigquery._table._Field at 0x10d6edb90>,
#  <gcp.bigquery._table._Field at 0x10d6edbd0>,
#  <gcp.bigquery._table._Field at 0x10d6edc10>,
#  <gcp.bigquery._table._Field at 0x10d6edc50>,
#  <gcp.bigquery._table._Field at 0x10d6edc90>,
#  <gcp.bigquery._table._Field at 0x10d6edcd0>,
#  <gcp.bigquery._table._Field at 0x10d6edd10>,
#  <gcp.bigquery._table._Field at 0x10d6edd50>,
#  <gcp.bigquery._table._Field at 0x10d6edd90>,
#  <gcp.bigquery._table._Field at 0x10d6eddd0>,
#  <gcp.bigquery._table._Field at 0x10d6ede10>,
#  <gcp.bigquery._table._Field at 0x10d6ede50>,
#  <gcp.bigquery._table._Field at 0x10d6ede90>,
#  <gcp.bigquery._table._Field at 0x10d6eded0>,
#  <gcp.bigquery._table._Field at 0x10d6edf10>,
#  <gcp.bigquery._table._Field at 0x10d6edf50>,
#  <gcp.bigquery._table._Field at 0x10d6edf90>,
#  <gcp.bigquery._table._Field at 0x10d6edfd0>,
#  <gcp.bigquery._table._Field at 0x10dc2e050>,
#  <gcp.bigquery._table._Field at 0x10dc2e090>,
#  <gcp.bigquery._table._Field at 0x10dc2e0d0>,
#  <gcp.bigquery._table._Field at 0x10dc2e110>,
#  <gcp.bigquery._table._Field at 0x10dc2e150>,
#  <gcp.bigquery._table._Field at 0x10dc2e190>,
#  <gcp.bigquery._table._Field at 0x10dc2e1d0>,
#  <gcp.bigquery._table._Field at 0x10dc2e210>,
#  <gcp.bigquery._table._Field at 0x10dc2e250>,
#  <gcp.bigquery._table._Field at 0x10dc2e290>,
#  <gcp.bigquery._table._Field at 0x10dc2e2d0>,
#  <gcp.bigquery._table._Field at 0x10dc2e310>,
#  <gcp.bigquery._table._Field at 0x10dc2e350>,
#  <gcp.bigquery._table._Field at 0x10dc2e390>,
#  <gcp.bigquery._table._Field at 0x10dc2e3d0>,
#  <gcp.bigquery._table._Field at 0x10dc2e410>,
#  <gcp.bigquery._table._Field at 0x10dc2e450>,
#  <gcp.bigquery._table._Field at 0x10dc2e490>,
#  <gcp.bigquery._table._Field at 0x10dc2e4d0>,
#  <gcp.bigquery._table._Field at 0x10dc2e510>,
#  <gcp.bigquery._table._Field at 0x10dc2e550>,
#  <gcp.bigquery._table._Field at 0x10dc2e590>,
#  <gcp.bigquery._table._Field at 0x10dc2e5d0>,
#  <gcp.bigquery._table._Field at 0x10dc2e610>,
#  <gcp.bigquery._table._Field at 0x10dc2e650>,
#  <gcp.bigquery._table._Field at 0x10dc2e690>,
#  <gcp.bigquery._table._Field at 0x10dc2e6d0>,
#  <gcp.bigquery._table._Field at 0x10dc2e710>,
#  <gcp.bigquery._table._Field at 0x10dc2e750>,
#  <gcp.bigquery._table._Field at 0x10dc2e790>,
#  <gcp.bigquery._table._Field at 0x10dc2e7d0>,
#  <gcp.bigquery._table._Field at 0x10dc2e810>,
#  <gcp.bigquery._table._Field at 0x10dc2e850>,
#  <gcp.bigquery._table._Field at 0x10dc2e890>,
#  <gcp.bigquery._table._Field at 0x10dc2e8d0>,
#  <gcp.bigquery._table._Field at 0x10dc2e910>,
#  <gcp.bigquery._table._Field at 0x10dc2e950>,
#  <gcp.bigquery._table._Field at 0x10dc2e990>,
#  <gcp.bigquery._table._Field at 0x10dc2e9d0>,
#  <gcp.bigquery._table._Field at 0x10dc2ea10>,
#  <gcp.bigquery._table._Field at 0x10dc2ea50>,
#  <gcp.bigquery._table._Field at 0x10dc2ea90>,
#  <gcp.bigquery._table._Field at 0x10dc2ead0>,
#  <gcp.bigquery._table._Field at 0x10dc2eb10>,
#  <gcp.bigquery._table._Field at 0x10dc2eb50>,
#  <gcp.bigquery._table._Field at 0x10dc2eb90>,
#  <gcp.bigquery._table._Field at 0x10dc2ebd0>,
#  <gcp.bigquery._table._Field at 0x10dc2ec10>,
#  <gcp.bigquery._table._Field at 0x10dc2ec50>,
#  <gcp.bigquery._table._Field at 0x10dc2ec90>,
#  <gcp.bigquery._table._Field at 0x10dc2ecd0>,
#  <gcp.bigquery._table._Field at 0x10dc2ed10>,
#  <gcp.bigquery._table._Field at 0x10dc2ed50>,
#  <gcp.bigquery._table._Field at 0x10dc2ed90>,
#  <gcp.bigquery._table._Field at 0x10dc2edd0>,
#  <gcp.bigquery._table._Field at 0x10dc2ee10>,
#  <gcp.bigquery._table._Field at 0x10dc2ee50>,
#  <gcp.bigquery._table._Field at 0x10dc2ee90>,
#  <gcp.bigquery._table._Field at 0x10dc2eed0>,
#  <gcp.bigquery._table._Field at 0x10dc2ef10>,
#  <gcp.bigquery._table._Field at 0x10dc2ef50>,
#  <gcp.bigquery._table._Field at 0x10dc2ef90>,
#  <gcp.bigquery._table._Field at 0x10dc2efd0>,
#  <gcp.bigquery._table._Field at 0x10dc2f050>,
#  <gcp.bigquery._table._Field at 0x10dc2f090>,
#  <gcp.bigquery._table._Field at 0x10dc2f0d0>,
#  <gcp.bigquery._table._Field at 0x10dc2f110>,
#  <gcp.bigquery._table._Field at 0x10dc2f150>,
#  <gcp.bigquery._table._Field at 0x10dc2f190>,
#  <gcp.bigquery._table._Field at 0x10dc2f1d0>,
#  <gcp.bigquery._table._Field at 0x10dc2f210>,
#  <gcp.bigquery._table._Field at 0x10dc2f250>,
#  <gcp.bigquery._table._Field at 0x10dc2f290>,
#  <gcp.bigquery._table._Field at 0x10dc2f2d0>,
#  <gcp.bigquery._table._Field at 0x10dc2f310>,
#  <gcp.bigquery._table._Field at 0x10dc2f350>,
#  <gcp.bigquery._table._Field at 0x10dc2f390>,
#  <gcp.bigquery._table._Field at 0x10dc2f3d0>,
#  <gcp.bigquery._table._Field at 0x10dc2f410>,
#  <gcp.bigquery._table._Field at 0x10dc2f450>,
#  <gcp.bigquery._table._Field at 0x10dc2f490>,
#  <gcp.bigquery._table._Field at 0x10dc2f4d0>,
#  <gcp.bigquery._table._Field at 0x10dc2f510>,
#  <gcp.bigquery._table._Field at 0x10dc2f550>,
#  <gcp.bigquery._table._Field at 0x10dc2f590>,
#  <gcp.bigquery._table._Field at 0x10dc2f5d0>,
#  <gcp.bigquery._table._Field at 0x10dc2f610>,
#  <gcp.bigquery._table._Field at 0x10dc2f650>,
#  <gcp.bigquery._table._Field at 0x10dc2f690>,
#  <gcp.bigquery._table._Field at 0x10dc2f6d0>,
#  <gcp.bigquery._table._Field at 0x10dc2f710>,
#  <gcp.bigquery._table._Field at 0x10dc2f750>,
#  <gcp.bigquery._table._Field at 0x10dc2f790>,
#  <gcp.bigquery._table._Field at 0x10dc2f7d0>,
#  <gcp.bigquery._table._Field at 0x10dc2f810>,
#  <gcp.bigquery._table._Field at 0x10dc2f850>,
#  <gcp.bigquery._table._Field at 0x10dc2f890>,
#  <gcp.bigquery._table._Field at 0x10dc2f8d0>,
#  <gcp.bigquery._table._Field at 0x10dc2f910>,
#  <gcp.bigquery._table._Field at 0x10dc2f950>,
#  <gcp.bigquery._table._Field at 0x10dc2f990>,
#  <gcp.bigquery._table._Field at 0x10dc2f9d0>,
#  <gcp.bigquery._table._Field at 0x10dc2fa10>,
#  <gcp.bigquery._table._Field at 0x10dc2fa50>,
#  <gcp.bigquery._table._Field at 0x10dc2fa90>,
#  <gcp.bigquery._table._Field at 0x10dc2fad0>,
#  <gcp.bigquery._table._Field at 0x10dc2fb10>,
#  <gcp.bigquery._table._Field at 0x10dc2fb50>,
#  <gcp.bigquery._table._Field at 0x10dc2fb90>,
#  <gcp.bigquery._table._Field at 0x10dc2fbd0>,
#  <gcp.bigquery._table._Field at 0x10dc2fc10>,
#  <gcp.bigquery._table._Field at 0x10dc2fc50>,
#  <gcp.bigquery._table._Field at 0x10dc2fc90>,
#  <gcp.bigquery._table._Field at 0x10dc2fcd0>,
#  <gcp.bigquery._table._Field at 0x10dc2fd10>,
#  <gcp.bigquery._table._Field at 0x10dc2fd50>,
#  <gcp.bigquery._table._Field at 0x10dc2fd90>,
#  <gcp.bigquery._table._Field at 0x10dc2fdd0>,
#  <gcp.bigquery._table._Field at 0x10dc2fe10>,
#  <gcp.bigquery._table._Field at 0x10dc2fe50>,
#  <gcp.bigquery._table._Field at 0x10dc2fe90>,
#  <gcp.bigquery._table._Field at 0x10dc2fed0>,
#  <gcp.bigquery._table._Field at 0x10dc2ff10>,
#  <gcp.bigquery._table._Field at 0x10dc2ff50>,
#  <gcp.bigquery._table._Field at 0x10dc2ff90>,
#  <gcp.bigquery._table._Field at 0x10dc2ffd0>,
#  <gcp.bigquery._table._Field at 0x10dc30050>,
#  <gcp.bigquery._table._Field at 0x10dc30090>,
#  <gcp.bigquery._table._Field at 0x10dc300d0>,
#  <gcp.bigquery._table._Field at 0x10dc30110>,
#  <gcp.bigquery._table._Field at 0x10dc30150>,
#  <gcp.bigquery._table._Field at 0x10dc30190>,
#  <gcp.bigquery._table._Field at 0x10dc301d0>,
#  <gcp.bigquery._table._Field at 0x10dc30210>,
#  <gcp.bigquery._table._Field at 0x10dc30250>,
#  <gcp.bigquery._table._Field at 0x10dc30290>,
#  <gcp.bigquery._table._Field at 0x10dc302d0>,
#  <gcp.bigquery._table._Field at 0x10dc30310>,
#  <gcp.bigquery._table._Field at 0x10dc30350>,
#  <gcp.bigquery._table._Field at 0x10dc30390>,
#  <gcp.bigquery._table._Field at 0x10dc303d0>,
#  <gcp.bigquery._table._Field at 0x10dc30410>,
#  <gcp.bigquery._table._Field at 0x10dc30450>,
#  <gcp.bigquery._table._Field at 0x10dc30490>,
#  <gcp.bigquery._table._Field at 0x10dc304d0>,
#  <gcp.bigquery._table._Field at 0x10dc30510>,
#  <gcp.bigquery._table._Field at 0x10dc30550>,
#  <gcp.bigquery._table._Field at 0x10dc30590>,
#  <gcp.bigquery._table._Field at 0x10dc305d0>,
#  <gcp.bigquery._table._Field at 0x10dc30610>,
#  <gcp.bigquery._table._Field at 0x10dc30650>,
#  <gcp.bigquery._table._Field at 0x10dc30690>,
#  <gcp.bigquery._table._Field at 0x10dc306d0>,
#  <gcp.bigquery._table._Field at 0x10dc30710>,
#  <gcp.bigquery._table._Field at 0x10dc30750>,
#  <gcp.bigquery._table._Field at 0x10dc30790>,
#  <gcp.bigquery._table._Field at 0x10dc307d0>,
#  <gcp.bigquery._table._Field at 0x10dc30810>,
#  <gcp.bigquery._table._Field at 0x10dc30850>,
#  <gcp.bigquery._table._Field at 0x10dc30890>,
#  <gcp.bigquery._table._Field at 0x10dc308d0>,
#  <gcp.bigquery._table._Field at 0x10dc30910>,
#  <gcp.bigquery._table._Field at 0x10dc30950>,
#  <gcp.bigquery._table._Field at 0x10dc30990>,
#  <gcp.bigquery._table._Field at 0x10dc309d0>,
#  <gcp.bigquery._table._Field at 0x10dc30a10>,
#  <gcp.bigquery._table._Field at 0x10dc30a50>,
#  <gcp.bigquery._table._Field at 0x10dc30a90>,
#  <gcp.bigquery._table._Field at 0x10dc30ad0>,
#  <gcp.bigquery._table._Field at 0x10dc30b10>,
#  <gcp.bigquery._table._Field at 0x10dc30b50>,
#  <gcp.bigquery._table._Field at 0x10dc30b90>,
#  <gcp.bigquery._table._Field at 0x10dc30bd0>,
#  <gcp.bigquery._table._Field at 0x10dc30c10>,
#  <gcp.bigquery._table._Field at 0x10dc30c50>,
#  <gcp.bigquery._table._Field at 0x10dc30c90>,
#  <gcp.bigquery._table._Field at 0x10dc30cd0>,
#  <gcp.bigquery._table._Field at 0x10dc30d10>,
#  <gcp.bigquery._table._Field at 0x10dc30d50>,
#  <gcp.bigquery._table._Field at 0x10dc30d90>,
#  <gcp.bigquery._table._Field at 0x10dc30dd0>,
#  <gcp.bigquery._table._Field at 0x10dc30e10>,
#  <gcp.bigquery._table._Field at 0x10dc30e50>,
#  <gcp.bigquery._table._Field at 0x10dc30e90>,
#  <gcp.bigquery._table._Field at 0x10dc30ed0>,
#  <gcp.bigquery._table._Field at 0x10dc30f10>,
#  <gcp.bigquery._table._Field at 0x10dc30f50>,
#  <gcp.bigquery._table._Field at 0x10dc30f90>,
#  <gcp.bigquery._table._Field at 0x10dc30fd0>]

# %% [markdown]
# Let's look at a few rows from the table for a few phenotype attributes of interest.

# %%
phenotypes.sample(fields=['Participant','Sex_Gender','Year_of_birth','Maternal_grandmother_Country_of_origin', 'Maternal_grandfather_Country_of_origin'])
# Out:
# [{u'Maternal_grandfather_Country_of_origin': u'United States',
#   u'Maternal_grandmother_Country_of_origin': u'United States',
#   u'Participant': u'huBFBBD8',
#   u'Sex_Gender': u'Male',
#   u'Year_of_birth': u'1973'},
#  {u'Maternal_grandfather_Country_of_origin': u'United States',
#   u'Maternal_grandmother_Country_of_origin': u'United States',
#   u'Participant': u'hu5880D9',
#   u'Sex_Gender': u'Female',
#   u'Year_of_birth': u'1986'},
#  {u'Maternal_grandfather_Country_of_origin': u'Austria',
#   u'Maternal_grandmother_Country_of_origin': u'Poland',
#   u'Participant': u'hu9367D1',
#   u'Sex_Gender': u'Male',
#   u'Year_of_birth': u'1987'},
#  {u'Maternal_grandfather_Country_of_origin': u'United States',
#   u'Maternal_grandmother_Country_of_origin': u'United States',
#   u'Participant': u'hu57850F',
#   u'Sex_Gender': u'Female',
#   u'Year_of_birth': u'1960'},
#  {u'Maternal_grandfather_Country_of_origin': u'China',
#   u'Maternal_grandmother_Country_of_origin': u'China',
#   u'Participant': u'hu1069B0',
#   u'Sex_Gender': u'Female',
#   u'Year_of_birth': None}]

# %% [markdown]
# ## Querying
#
# Let's dig further into the phenotypes table and get some statistics on the occurrence of asthma among the participants present within the dataset. The `%%bq_sql` statement allows us to write SQL within our notebook and execute it within BigQuery.

# %%
# %%bq_sql asthma
# SELECT
#   Participant,
#   IFNULL(Sex_Gender, 'Unknown') AS gender,
#   IF(has_Asthma IS NULL, 0, 1) AS has_asthma
# FROM
#   $phenotypes

# %% [markdown]
# Our query is now stored in a variable called `asthma`. We can execute the query (by sending to BigQuery) by calling `asthma.results()`.  Additionally, let's convert the results to a [Pandas dataframe](http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html) so that we can slice off just the first 5 rows.

# %%
asthma.results().to_dataframe()[:5]
# Out:
#   Participant  gender  has_asthma
# 0    huBFBBD8    Male           0
# 1    hu5880D9  Female           0
# 2    hu9367D1    Male           0
# 3    hu57850F  Female           0
# 4    hu1069B0  Female           0

# %% [markdown]
# #### Composing Queries
#
# Now that we've seen the structure of the rows generated by our `$asthma` query, let's summarize the results by computing the percentage of the overall dataset having asthma. We can accomplish this by nesting our previous query within an outer `SELECT` statement. The `%%bq_sql` statement allows us to embed our previous `$asthma` query like so:

# %%
# %%bq_sql
# SELECT ROUND(AVG(has_asthma) * 100, 2) AS percent_has_asthma
# FROM $asthma
# Out:
# [{u'percent_has_asthma': 9.1}]

# %% [markdown]
# Notice the reference to the previous query we defined via the `$asthma` placeholder. The resulting query is a nested SQL statement.  We can see the full, nested query that was generated:

# %%
print asthma.sql
# Out:
# SELECT
#   Participant,
#   IFNULL(Sex_Gender, 'Unknown') AS gender,
#   IF(has_Asthma IS NULL, 0, 1) AS has_asthma
# FROM
#   [google.com:biggene:pgp.phenotypes]

# %% [markdown]
# This is handy because we can build up our large, complex query one piece at a time and validate that the intermediate results we're getting along the way.
#
# Let's further refine our `$asthma` query and compute the average occurrence broken down by gender this time.

# %%
# %%bq_sql
# SELECT
#   gender,
#   ROUND(AVG(has_asthma) * 100, 2) AS percent_has_asthma
# FROM $asthma
# GROUP BY
#   gender
# Out:
# [{u'gender': u'Male', u'percent_has_asthma': 6.8},
#  {u'gender': u'Female', u'percent_has_asthma': 12.03},
#  {u'gender': u'Transmasculine ', u'percent_has_asthma': 0.0},
#  {u'gender': u'Unknown', u'percent_has_asthma': 13.92}]

# %% [markdown]
# Looks like there are roughly twice as many female (versus male) genomes with the asthma phenotype in this dataset.

# %% [markdown]
# ## Python Pandas Integration
#
# Since our `$asthma` query returns a result set that is small enough to easily fit into memory (at ~2k rows), let's create a local dataset from our query by populating a [Pandas dataframe](http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html) object and saving it to the `df` variable.

# %%
df = asthma.results().to_dataframe()

# %% [markdown]
# This dataframe allows us to slice and dice our data in a number of ways and all of the computation will happen locally. Let's try getting the number of genomes per gender via our dataframe.

# %%
df.groupby('gender').sum()
# Out:
#                  has_asthma
# gender
# Female                  103
# Male                     85
# Transmasculine            0
# Unknown                  11

# %% [markdown]
# So that shows us the total number of participants annotated to have asthma, broken down by gender. Let's see if we can reproduce the percent_has_asthma column that we computed above via BigQuery.

# %%
df.groupby('gender').mean() * 100
# Out:
#                  has_asthma
# gender
# Female            12.032710
# Male               6.800000
# Transmasculine     0.000000
# Unknown           13.924051

# %% [markdown]
# Great! So for datasets that easily fit into memory, we can easily aggregate our results via the Pandas dataframe using an approach very similar to our SQL statement.

# %% [markdown]
# ## Visualization
#
# Every Pandas dataframe can be used for visualization by calling the [`dataframe.plot()`](http://pandas.pydata.org/pandas-docs/dev/visualization.html) method.  Let's plot the counts of asthma occurrence broken down by gender.

# %%
tally = df.groupby('gender').sum()
tally.plot(kind='pie', y='has_asthma', legend=False)
tally.plot(kind='bar', y='has_asthma', legend=False)

# %% [markdown]
# # Exploring the 1000 Genomes datasets
#
# Now let's look at a different genome dataset provided by the [1000 Genomes project](http://www.1000genomes.org/).  We'll start by taking a look at the gender ratio for participants in the genome dataset.

# %%
# %%bq_sql genders
# SELECT
#   gender,
#   gender_count,
#   RATIO_TO_REPORT(gender_count)
# OVER
#   (
#   ORDER BY
#     gender_count) AS gender_ratio
# FROM (
#   SELECT
#     gender,
#     COUNT(gender) AS gender_count,
#   FROM
#     [genomics-public-data:1000_genomes.sample_info]
#   GROUP BY
#     gender)

# %%
genders_df = genders.results().to_dataframe()
genders_df[:10]
# Out:
#    gender  gender_count  gender_ratio
# 0    male          1740      0.497143
# 1  female          1760      0.502857

# %%
genders_df.plot(kind='barh', y='gender_count', label='genders', legend=False)

# %% [markdown]
# So we see the gender break down is roughly equal within the dataset.
#
# Now let's see how our genomes are distributed across different world populations and super population groups.

# %%
# %%bq_sql pops
# SELECT
#   population,
#   population_description,
#   super_population,
#   super_population_description,
#   COUNT(population) AS population_count,
# FROM
#   [genomics-public-data:1000_genomes.sample_info]
# GROUP BY
#   population,
#   population_description,
#   super_population,
#   super_population_description

# %%
pops.results()
# Out:
# [{u'population': u'GBR',
#   u'population_count': 107,
#   u'population_description': u'British in England and Scotland',
#   u'super_population': u'EUR',
#   u'super_population_description': u'European'},
#  {u'population': u'FIN',
#   u'population_count': 105,
#   u'population_description': u'Finnish in Finland',
#   u'super_population': u'EUR',
#   u'super_population_description': u'European'},
#  {u'population': u'CHS',
#   u'population_count': 171,
#   u'population_description': u'Southern Han Chinese, China',
#   u'super_population': u'EAS',
#   u'super_population_description': u'East Asian'},
#  {u'population': u'PUR',
#   u'population_count': 150,
#   u'population_description': u'Puerto Rican in Puerto Rico',
#   u'super_population': u'AMR',
#   u'super_population_description': u'American'},
#  {u'population': u'CDX',
#   u'population_count': 109,
#   u'population_description': u'Chinese Dai in Xishuangbanna, China',
#   u'super_population': u'EAS',
#   u'super_population_description': u'East Asian'},
#  {u'population': u'CLM',
#   u'population_count': 148,
#   u'population_description': u'Colombian in Medellin, Colombia',
#   u'super_population': u'AMR',
#   u'super_population_description': u'American'},
#  {u'population': u'IBS',
#   u'population_count': 162,
#   u'population_description': u'Iberian populations in Spain',
#   u'super_population': u'EUR',
#   u'super_population_description': u'European'},
#  {u'population': u'PEL',
#   u'population_count': 130,
#   u'population_description': u'Peruvian in Lima, Peru',
#   u'super_population': u'AMR',
#   u'super_population_description': u'American'},
#  {u'population': u'PJL',
#   u'population_count': 158,
#   u'population_description': u'Punjabi in Lahore,Pakistan',
#   u'super_population': u'SAS',
#   u'super_population_description': u'South Asian'},
#  {u'population': u'KHV',
#   u'population_count': 124,
#   u'population_description': u'Kinh in Ho Chi Minh City, Vietnam',
#   u'super_population': u'EAS',
#   u'super_population_description': u'East Asian'},
#  {u'population': u'ACB',
#   u'population_count': 123,
#   u'population_description': u'African Caribbean in Barbados',
#   u'super_population': u'AFR',
#   u'super_population_description': u'African'},
#  {u'population': u'GWD',
#   u'population_count': 180,
#   u'population_description': u'Gambian in Western Division, The Gambia',
#   u'super_population': u'AFR',
#   u'super_population_description': u'African'},
#  {u'population': u'ESN',
#   u'population_count': 173,
#   u'population_description': u'Esan in Nigeria',
#   u'super_population': u'AFR',
#   u'super_population_description': u'African'},
#  {u'population': u'BEB',
#   u'population_count': 144,
#   u'population_description': u'Bengali in Bangladesh',
#   u'super_population': u'SAS',
#   u'super_population_description': u'South Asian'},
#  {u'population': u'MSL',
#   u'population_count': 128,
#   u'population_description': u'Mende in Sierra Leone',
#   u'super_population': u'AFR',
#   u'super_population_description': u'African'},
#  {u'population': u'STU',
#   u'population_count': 128,
#   u'population_description': u'Sri Lankan Tamil in the UK',
#   u'super_population': u'SAS',
#   u'super_population_description': u'South Asian'},
#  {u'population': u'ITU',
#   u'population_count': 118,
#   u'population_description': u'Indian Telugu in the UK',
#   u'super_population': u'SAS',
#   u'super_population_description': u'South Asian'},
#  {u'population': u'CEU',
#   u'population_count': 183,
#   u'population_description': u'Utah residents with Northern and Western European ancestry',
#   u'super_population': u'EUR',
#   u'super_population_description': u'European'},
#  {u'population': u'YRI',
#   u'population_count': 186,
#   u'population_description': u'Yoruba in Ibadan, Nigeria',
#   u'super_population': u'AFR',
#   u'super_population_description': u'African'},
#  {u'population': u'CHB',
#   u'population_count': 108,
#   u'population_description': u'Han Chinese in Bejing, China',
#   u'super_population': u'EAS',
#   u'super_population_description': u'East Asian'},
#  {u'population': u'JPT',
#   u'population_count': 105,
#   u'population_description': u'Japanese in Tokyo, Japan',
#   u'super_population': u'EAS',
#   u'super_population_description': u'East Asian'},
#  {u'population': u'LWK',
#   u'population_count': 116,
#   u'population_description': u'Luhya in Webuye, Kenya',
#   u'super_population': u'AFR',
#   u'super_population_description': u'African'},
#  {u'population': u'ASW',
#   u'population_count': 112,
#   u'population_description': u'African Ancestry in Southwest US',
#   u'super_population': u'AFR',
#   u'super_population_description': u'African'},
#  {u'population': u'MXL',
#   u'population_count': 107,
#   u'population_description': u'Mexican Ancestry in Los Angeles, California',
#   u'super_population': u'AMR',
#   u'super_population_description': u'American'},
#  {u'population': u'TSI',
#   u'population_count': 112,
#   u'population_description': u'Toscani in Italy',
#   u'super_population': u'EUR',
#   u'super_population_description': u'European'},
#  {u'population': u'GIH',
#   u'population_count': 113,
#   u'population_description': u'Gujarati Indian in Houston,TX',
#   u'super_population': u'SAS',
#   u'super_population_description': u'South Asian'}]

# %% [markdown]
# Continuing further, let's calculate the fraction of each population's contribution to the whole using the [`RATIO_TO_REPORT`](https://cloud.google.com/bigquery/query-reference#windowfunctions) BigQuery analytic function, which gives us the fractional contribution of each population to the total dataset.

# %%
# %%bq_sql pops_ratio
# SELECT
#   population,
#   population_description,
#   population_count,
#   RATIO_TO_REPORT(population_count)
#     OVER (ORDER BY population_count) AS population_ratio,
#   super_population,
#   super_population_description,
# FROM ($pops)

# %%
pops_df = pops_ratio.results().to_dataframe()
pops_df
# Out:
#    population  population_count  \
# 0         FIN               105
# 1         JPT               105
# 2         GBR               107
# 3         MXL               107
# 4         CHB               108
# 5         CDX               109
# 6         TSI               112
# 7         ASW               112
# 8         GIH               113
# 9         LWK               116
# 10        ITU               118
# 11        ACB               123
# 12        KHV               124
# 13        MSL               128
# 14        STU               128
# 15        PEL               130
# 16        BEB               144
# 17        CLM               148
# 18        PUR               150
# 19        PJL               158
# 20        IBS               162
# 21        CHS               171
# 22        ESN               173
# 23        GWD               180
# 24        CEU               183
# 25        YRI               186
#
#                                population_description  population_ratio  \
# 0                                  Finnish in Finland          0.030000
# 1                            Japanese in Tokyo, Japan          0.030000
# 2                     British in England and Scotland          0.030571
# 3         Mexican Ancestry in Los Angeles, California          0.030571
# 4                        Han Chinese in Bejing, China          0.030857
# 5                 Chinese Dai in Xishuangbanna, China          0.031143
# 6                                    Toscani in Italy          0.032000
# 7                    African Ancestry in Southwest US          0.032000
# 8                       Gujarati Indian in Houston,TX          0.032286
# 9                              Luhya in Webuye, Kenya          0.033143
# 10                            Indian Telugu in the UK          0.033714
# 11                      African Caribbean in Barbados          0.035143
# 12                  Kinh in Ho Chi Minh City, Vietnam          0.035429
# 13                              Mende in Sierra Leone          0.036571
# 14                         Sri Lankan Tamil in the UK          0.036571
# 15                             Peruvian in Lima, Peru          0.037143
# 16                              Bengali in Bangladesh          0.041143
# 17                    Colombian in Medellin, Colombia          0.042286
# 18                        Puerto Rican in Puerto Rico          0.042857
# 19                         Punjabi in Lahore,Pakistan          0.045143
# 20                       Iberian populations in Spain          0.046286
# 21                        Southern Han Chinese, China          0.048857
# 22                                    Esan in Nigeria          0.049429
# 23            Gambian in Western Division, The Gambia          0.051429
# 24  Utah residents with Northern and Western Europ...          0.052286
# 25                          Yoruba in Ibadan, Nigeria          0.053143
#
#    super_population super_population_description
# 0               EUR                     European
# 1               EAS                   East Asian
# 2               EUR                     European
# 3               AMR                     American
# 4               EAS                   East Asian
# 5               EAS                   East Asian
# 6               EUR                     European
# 7               AFR                      African
# 8               SAS                  South Asian
# 9               AFR                      African
# 10              SAS                  South Asian
# 11              AFR                      African
# 12              EAS                   East Asian
# 13              AFR                      African
# 14              SAS                  South Asian
# 15              AMR                     American
# 16              SAS                  South Asian
# 17              AMR                     American
# 18              AMR                     American
# 19              SAS                  South Asian
# 20              EUR                     European
# 21              EAS                   East Asian
# 22              AFR                      African
# 23              AFR                      African
# 24              EUR                     European
# 25              AFR                      African

# %% [markdown]
# Let's visualize the number of genomes available per population group as a bar chart.  We can simply use our Pandas dataframe to plot the dimensions of interest.

# %%
pops_df.groupby('population').sum().plot(kind='bar', y='population_count', legend=False)

# %% [markdown]
# What are the ratios of ethnicities grouped by super population? We can find out by aggregating our local dataset via the Pandas dataframe.

# %%
pops_df.groupby('super_population').sum().plot(kind='bar', y='population_count', legend=False)

# %% [markdown]
# Some of the dataset participants happen to be relatives. Let's see how the family size is distributed among the genomes available:

# %%
# %%bq_sql family_sizes
# SELECT
#   num_family_members AS family_size,
#   COUNT(num_family_members) AS num_families_of_size
# FROM (
#   SELECT
#     family_id,
#     COUNT(family_id) AS num_family_members,
#   FROM
#     [genomics-public-data:1000_genomes.sample_info]
#   GROUP BY
#     family_id)
# GROUP BY
#   family_size

# %%
family_sizes_df = family_sizes.results().to_dataframe()
family_sizes_df
# Out:
#    family_size  num_families_of_size
# 0            1                  1185
# 1            2                   191
# 2            3                   593
# 3            4                     1
# 4            5                     6
# 5            6                    20

# %% [markdown]
# So we see that while the majority of participants do not have any relatives within the dataset, there are ~200 two-person families present and many fewer 3-person and larger families.
#
# We can plot the family size distribution using the dataframe again.

# %%
family_sizes_df.plot(x='family_size')
