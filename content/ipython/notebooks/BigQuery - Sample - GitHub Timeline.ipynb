# %% [markdown]
# # BigQuery - Sample - GitHub Timeline
#
# This notebook demonstrates working with GitHub activity made possible via the publicly accessible GitHub Timeline BigQuery dataset via the [GitHub Archive project](http://www.githubarchive.org/).
#
# As an interesting question, it attempts to determine "_how likely are you to program in X, if you program in Y_." For example, this might be an input into an repository exploration/recommendation/search tool to personalize the results based on your own contributions.
#
# It is based on an example published at http://datahackermd.com/2013/language-use-on-github/. It counts pushes or commits made by all users across all repositories on GitHub, and their associated repository languages, to determine the correlation between languages.
#
# ### In this notebook you will
# * Explore the BigQuery data schema for the Github Archive via the `gcp.bigquery` library
# * Use the `%%bq_sql` statement to write and execute SQL statements within the notebook
# * Extract data from BigQuery and create a local dataset that can be manipulated in Python
# * Refine and pivot your local dataset via the Pandas Python library
# * Visualize different aspects of your dataset via the Matplotlib Python library
#
# Related Links:
#
# * [BigQuery](https://cloud.google.com/bigquery/)
# * BigQuery [SQL reference](https://cloud.google.com/bigquery/query-reference)
# * Python [Pandas](http://pandas.pydata.org/) for data analysis
# * Python [matplotlib](http://matplotlib.org/) for data visualization
#
#
# ----
#
# NOTE:
#
# * The notebooks contains a snapshot of results (as of Oct 28th 2014) from previously executed code. You can simply read through the code and results, or execute each cell along the way, to get latest results.
# * For an introduction to BigQuery and notebook basics, see the [full list](..) of intro notebooks.
#
# ----

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import gcp.bigquery as bq

# %% [markdown]
# # Understanding the Data

# %% [markdown]
# We're going to work with the GitHub Archive project data.  It contains all github events (commits, pushes, forks, watches, etc.) along with metadata about the events (e.g., user, time, place).
#
# First, lets check out the table schema.

# %% [markdown]
# ## Schema

# %%
table = bq.table('githubarchive:github.timeline')
table.schema()
# Out:
# [<gcp.bigquery._table._Field at 0x10600d2d0>,
#  <gcp.bigquery._table._Field at 0x10600d290>,
#  <gcp.bigquery._table._Field at 0x10600d250>,
#  <gcp.bigquery._table._Field at 0x10600d210>,
#  <gcp.bigquery._table._Field at 0x10600d1d0>,
#  <gcp.bigquery._table._Field at 0x10600d190>,
#  <gcp.bigquery._table._Field at 0x10600d150>,
#  <gcp.bigquery._table._Field at 0x10600d110>,
#  <gcp.bigquery._table._Field at 0x10600d950>,
#  <gcp.bigquery._table._Field at 0x10600d990>,
#  <gcp.bigquery._table._Field at 0x10600d9d0>,
#  <gcp.bigquery._table._Field at 0x10600da10>,
#  <gcp.bigquery._table._Field at 0x10600da50>,
#  <gcp.bigquery._table._Field at 0x10600da90>,
#  <gcp.bigquery._table._Field at 0x10600dad0>,
#  <gcp.bigquery._table._Field at 0x10600db10>,
#  <gcp.bigquery._table._Field at 0x10600db50>,
#  <gcp.bigquery._table._Field at 0x10600db90>,
#  <gcp.bigquery._table._Field at 0x10600dbd0>,
#  <gcp.bigquery._table._Field at 0x10600dc10>,
#  <gcp.bigquery._table._Field at 0x10600dc50>,
#  <gcp.bigquery._table._Field at 0x10600dc90>,
#  <gcp.bigquery._table._Field at 0x10600dcd0>,
#  <gcp.bigquery._table._Field at 0x10600dd10>,
#  <gcp.bigquery._table._Field at 0x10600dd50>,
#  <gcp.bigquery._table._Field at 0x10600dd90>,
#  <gcp.bigquery._table._Field at 0x10600ddd0>,
#  <gcp.bigquery._table._Field at 0x10600de10>,
#  <gcp.bigquery._table._Field at 0x10600de50>,
#  <gcp.bigquery._table._Field at 0x10600de90>,
#  <gcp.bigquery._table._Field at 0x10600ded0>,
#  <gcp.bigquery._table._Field at 0x10600df10>,
#  <gcp.bigquery._table._Field at 0x10600df50>,
#  <gcp.bigquery._table._Field at 0x10600df90>,
#  <gcp.bigquery._table._Field at 0x10600dfd0>,
#  <gcp.bigquery._table._Field at 0x106569050>,
#  <gcp.bigquery._table._Field at 0x106569090>,
#  <gcp.bigquery._table._Field at 0x1065690d0>,
#  <gcp.bigquery._table._Field at 0x106569110>,
#  <gcp.bigquery._table._Field at 0x106569150>,
#  <gcp.bigquery._table._Field at 0x106569190>,
#  <gcp.bigquery._table._Field at 0x1065691d0>,
#  <gcp.bigquery._table._Field at 0x106569210>,
#  <gcp.bigquery._table._Field at 0x106569250>,
#  <gcp.bigquery._table._Field at 0x106569290>,
#  <gcp.bigquery._table._Field at 0x1065692d0>,
#  <gcp.bigquery._table._Field at 0x106569310>,
#  <gcp.bigquery._table._Field at 0x106569350>,
#  <gcp.bigquery._table._Field at 0x106569390>,
#  <gcp.bigquery._table._Field at 0x1065693d0>,
#  <gcp.bigquery._table._Field at 0x106569410>,
#  <gcp.bigquery._table._Field at 0x106569450>,
#  <gcp.bigquery._table._Field at 0x106569490>,
#  <gcp.bigquery._table._Field at 0x1065694d0>,
#  <gcp.bigquery._table._Field at 0x106569510>,
#  <gcp.bigquery._table._Field at 0x106569550>,
#  <gcp.bigquery._table._Field at 0x106569590>,
#  <gcp.bigquery._table._Field at 0x1065695d0>,
#  <gcp.bigquery._table._Field at 0x106569610>,
#  <gcp.bigquery._table._Field at 0x106569650>,
#  <gcp.bigquery._table._Field at 0x106569690>,
#  <gcp.bigquery._table._Field at 0x1065696d0>,
#  <gcp.bigquery._table._Field at 0x106569710>,
#  <gcp.bigquery._table._Field at 0x106569750>,
#  <gcp.bigquery._table._Field at 0x106569790>,
#  <gcp.bigquery._table._Field at 0x1065697d0>,
#  <gcp.bigquery._table._Field at 0x106569810>,
#  <gcp.bigquery._table._Field at 0x106569850>,
#  <gcp.bigquery._table._Field at 0x106569890>,
#  <gcp.bigquery._table._Field at 0x1065698d0>,
#  <gcp.bigquery._table._Field at 0x106569910>,
#  <gcp.bigquery._table._Field at 0x106569950>,
#  <gcp.bigquery._table._Field at 0x106569990>,
#  <gcp.bigquery._table._Field at 0x1065699d0>,
#  <gcp.bigquery._table._Field at 0x106569a10>,
#  <gcp.bigquery._table._Field at 0x106569a50>,
#  <gcp.bigquery._table._Field at 0x106569a90>,
#  <gcp.bigquery._table._Field at 0x106569ad0>,
#  <gcp.bigquery._table._Field at 0x106569b10>,
#  <gcp.bigquery._table._Field at 0x106569b50>,
#  <gcp.bigquery._table._Field at 0x106569b90>,
#  <gcp.bigquery._table._Field at 0x106569bd0>,
#  <gcp.bigquery._table._Field at 0x106569c10>,
#  <gcp.bigquery._table._Field at 0x106569c50>,
#  <gcp.bigquery._table._Field at 0x106569c90>,
#  <gcp.bigquery._table._Field at 0x106569cd0>,
#  <gcp.bigquery._table._Field at 0x106569d10>,
#  <gcp.bigquery._table._Field at 0x106569d50>,
#  <gcp.bigquery._table._Field at 0x106569d90>,
#  <gcp.bigquery._table._Field at 0x106569dd0>,
#  <gcp.bigquery._table._Field at 0x106569e10>,
#  <gcp.bigquery._table._Field at 0x106569e50>,
#  <gcp.bigquery._table._Field at 0x106569e90>,
#  <gcp.bigquery._table._Field at 0x106569ed0>,
#  <gcp.bigquery._table._Field at 0x106569f10>,
#  <gcp.bigquery._table._Field at 0x106569f50>,
#  <gcp.bigquery._table._Field at 0x106569f90>,
#  <gcp.bigquery._table._Field at 0x106569fd0>,
#  <gcp.bigquery._table._Field at 0x10656a050>,
#  <gcp.bigquery._table._Field at 0x10656a090>,
#  <gcp.bigquery._table._Field at 0x10656a0d0>,
#  <gcp.bigquery._table._Field at 0x10656a110>,
#  <gcp.bigquery._table._Field at 0x10656a150>,
#  <gcp.bigquery._table._Field at 0x10656a190>,
#  <gcp.bigquery._table._Field at 0x10656a1d0>,
#  <gcp.bigquery._table._Field at 0x10656a210>,
#  <gcp.bigquery._table._Field at 0x10656a250>,
#  <gcp.bigquery._table._Field at 0x10656a290>,
#  <gcp.bigquery._table._Field at 0x10656a2d0>,
#  <gcp.bigquery._table._Field at 0x10656a310>,
#  <gcp.bigquery._table._Field at 0x10656a350>,
#  <gcp.bigquery._table._Field at 0x10656a390>,
#  <gcp.bigquery._table._Field at 0x10656a3d0>,
#  <gcp.bigquery._table._Field at 0x10656a410>,
#  <gcp.bigquery._table._Field at 0x10656a450>,
#  <gcp.bigquery._table._Field at 0x10656a490>,
#  <gcp.bigquery._table._Field at 0x10656a4d0>,
#  <gcp.bigquery._table._Field at 0x10656a510>,
#  <gcp.bigquery._table._Field at 0x10656a550>,
#  <gcp.bigquery._table._Field at 0x10656a590>,
#  <gcp.bigquery._table._Field at 0x10656a5d0>,
#  <gcp.bigquery._table._Field at 0x10656a610>,
#  <gcp.bigquery._table._Field at 0x10656a650>,
#  <gcp.bigquery._table._Field at 0x10656a690>,
#  <gcp.bigquery._table._Field at 0x10656a6d0>,
#  <gcp.bigquery._table._Field at 0x10656a710>,
#  <gcp.bigquery._table._Field at 0x10656a750>,
#  <gcp.bigquery._table._Field at 0x10656a790>,
#  <gcp.bigquery._table._Field at 0x10656a7d0>,
#  <gcp.bigquery._table._Field at 0x10656a810>,
#  <gcp.bigquery._table._Field at 0x10656a850>,
#  <gcp.bigquery._table._Field at 0x10656a890>,
#  <gcp.bigquery._table._Field at 0x10656a8d0>,
#  <gcp.bigquery._table._Field at 0x10656a910>,
#  <gcp.bigquery._table._Field at 0x10656a950>,
#  <gcp.bigquery._table._Field at 0x10656a990>,
#  <gcp.bigquery._table._Field at 0x10656a9d0>,
#  <gcp.bigquery._table._Field at 0x10656aa10>,
#  <gcp.bigquery._table._Field at 0x10656aa50>,
#  <gcp.bigquery._table._Field at 0x10656aa90>,
#  <gcp.bigquery._table._Field at 0x10656aad0>,
#  <gcp.bigquery._table._Field at 0x10656ab10>,
#  <gcp.bigquery._table._Field at 0x10656ab50>,
#  <gcp.bigquery._table._Field at 0x10656ab90>,
#  <gcp.bigquery._table._Field at 0x10656abd0>,
#  <gcp.bigquery._table._Field at 0x10656ac10>,
#  <gcp.bigquery._table._Field at 0x10656ac50>,
#  <gcp.bigquery._table._Field at 0x10656ac90>,
#  <gcp.bigquery._table._Field at 0x10656acd0>,
#  <gcp.bigquery._table._Field at 0x10656ad10>,
#  <gcp.bigquery._table._Field at 0x10656ad50>,
#  <gcp.bigquery._table._Field at 0x10656ad90>,
#  <gcp.bigquery._table._Field at 0x10656add0>,
#  <gcp.bigquery._table._Field at 0x10656ae10>,
#  <gcp.bigquery._table._Field at 0x10656ae50>,
#  <gcp.bigquery._table._Field at 0x10656ae90>,
#  <gcp.bigquery._table._Field at 0x10656aed0>,
#  <gcp.bigquery._table._Field at 0x10656af10>,
#  <gcp.bigquery._table._Field at 0x10656af50>,
#  <gcp.bigquery._table._Field at 0x10656af90>,
#  <gcp.bigquery._table._Field at 0x10656afd0>,
#  <gcp.bigquery._table._Field at 0x10656b050>,
#  <gcp.bigquery._table._Field at 0x10656b090>,
#  <gcp.bigquery._table._Field at 0x10656b0d0>,
#  <gcp.bigquery._table._Field at 0x10656b110>,
#  <gcp.bigquery._table._Field at 0x10656b150>,
#  <gcp.bigquery._table._Field at 0x10656b190>,
#  <gcp.bigquery._table._Field at 0x10656b1d0>,
#  <gcp.bigquery._table._Field at 0x10656b210>,
#  <gcp.bigquery._table._Field at 0x10656b250>,
#  <gcp.bigquery._table._Field at 0x10656b290>,
#  <gcp.bigquery._table._Field at 0x10656b2d0>,
#  <gcp.bigquery._table._Field at 0x10656b310>,
#  <gcp.bigquery._table._Field at 0x10656b350>,
#  <gcp.bigquery._table._Field at 0x10656b390>,
#  <gcp.bigquery._table._Field at 0x10656b3d0>,
#  <gcp.bigquery._table._Field at 0x10656b410>,
#  <gcp.bigquery._table._Field at 0x10656b450>,
#  <gcp.bigquery._table._Field at 0x10656b490>,
#  <gcp.bigquery._table._Field at 0x10656b4d0>,
#  <gcp.bigquery._table._Field at 0x10656b510>,
#  <gcp.bigquery._table._Field at 0x10656b550>,
#  <gcp.bigquery._table._Field at 0x10656b590>,
#  <gcp.bigquery._table._Field at 0x10656b5d0>,
#  <gcp.bigquery._table._Field at 0x10656b610>,
#  <gcp.bigquery._table._Field at 0x10656b650>,
#  <gcp.bigquery._table._Field at 0x10656b690>,
#  <gcp.bigquery._table._Field at 0x10656b6d0>,
#  <gcp.bigquery._table._Field at 0x10656b710>,
#  <gcp.bigquery._table._Field at 0x10656b750>,
#  <gcp.bigquery._table._Field at 0x10656b790>,
#  <gcp.bigquery._table._Field at 0x10656b7d0>,
#  <gcp.bigquery._table._Field at 0x10656b810>,
#  <gcp.bigquery._table._Field at 0x10656b850>,
#  <gcp.bigquery._table._Field at 0x10656b890>,
#  <gcp.bigquery._table._Field at 0x10656b8d0>,
#  <gcp.bigquery._table._Field at 0x10656b910>,
#  <gcp.bigquery._table._Field at 0x10656b950>,
#  <gcp.bigquery._table._Field at 0x10656b990>]

# %% [markdown]
# The GitHub timeline is a fairly large dataset. A quick lookup of table metadata gives us the row count.

# %%
int(table.metadata().rows)
# Out:
# 263855065

# %% [markdown]
# ## Sampling the Data

# %% [markdown]
# With over 262 million events, it is important to be able to sample the data. The sample method allows you to sample tables, or queries.

# %%
table.sample(fields=['repository_name',
                     'repository_language',
                     'created_at',
                     'type'])
# Out:
# [{u'created_at': u'2014-06-11 13:05:31',
#   u'repository_language': None,
#   u'repository_name': u'miniquery',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-06-11 13:05:30',
#   u'repository_language': u'JavaScript',
#   u'repository_name': u'chap-links-library',
#   u'type': u'IssuesEvent'},
#  {u'created_at': u'2014-06-11 13:05:30',
#   u'repository_language': u'JavaScript',
#   u'repository_name': u'chap-links-library',
#   u'type': u'IssueCommentEvent'},
#  {u'created_at': u'2014-06-11 13:05:30',
#   u'repository_language': u'JavaScript',
#   u'repository_name': u'youtube-google-analytics',
#   u'type': u'ForkEvent'},
#  {u'created_at': u'2014-06-11 13:05:30',
#   u'repository_language': u'Objective-C',
#   u'repository_name': u'MailCore',
#   u'type': u'IssueCommentEvent'}]

# %% [markdown]
# ## Data Exploration with SQL

# %% [markdown]
# This SQL statement will pull a few interesting fields corresponding to repository creation events recorded in the GitHub timeline, ordered with most recent first.

# %%
# %%bq_sql
# SELECT repository_name, type, created_at, repository_language
# FROM [githubarchive:github.timeline]
# WHERE type = 'CreateEvent'
# ORDER BY created_at DESC
# LIMIT 5
# Out:
# [{u'created_at': u'2014-10-30 18:05:38',
#   u'repository_language': u'Ruby',
#   u'repository_name': u'etsydemo2',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-10-30 18:05:36',
#   u'repository_language': None,
#   u'repository_name': u'hvpc',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-10-30 18:05:35',
#   u'repository_language': u'CoffeeScript',
#   u'repository_name': u'node-lshift',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-10-30 18:05:34',
#   u'repository_language': u'Ruby',
#   u'repository_name': u'myapp',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-10-30 18:05:33',
#   u'repository_language': u'JavaScript',
#   u'repository_name': u'picturefill',
#   u'type': u'CreateEvent'}]

# %% [markdown]
# # Querying the Data

# %% [markdown]
# The first step in our analysis to correlate languages is going to be retrieving the appropriate slice of data.
#
# We'll need to retrieve the list of PushEvents from the timeline. This is going to be a fairly large list of events, so there are a couple of ways to get a more manageable resultset:
#
# * Limiting the analysis to the top 25 languages (from an otherwise really long list of languages which simply add noise).
# * Limiting the analysis to just pushes made during 1 year time window.
# * Further sampling to get a small, but still interesting sample set to analyze further for correlation.

# %% [markdown]
# ## Finding the Popular Languages

# %%
# %%bq_sql popular_languages
# SELECT repository_language, COUNT(repository_language) as pushes
# FROM [githubarchive:github.timeline]
# WHERE type = 'PushEvent'
#   AND repository_language != ''
#   AND PARSE_UTC_USEC(created_at) >= DATE_ADD(CURRENT_TIMESTAMP(), -1, 'YEAR')
# GROUP BY repository_language
# ORDER BY pushes DESC
# LIMIT 25

# %% [markdown]
# The `popular_languages` query defined above can be executed to see the results (as done below) or referenced in subsequent queries (as shown later).

# %%
popular_languages.results()
# Out:
# [{u'pushes': 10689196, u'repository_language': u'JavaScript'},
#  {u'pushes': 7167562, u'repository_language': u'Java'},
#  {u'pushes': 5620404, u'repository_language': u'Python'},
#  {u'pushes': 5319109, u'repository_language': u'CSS'},
#  {u'pushes': 4551505, u'repository_language': u'PHP'},
#  {u'pushes': 4273057, u'repository_language': u'Ruby'},
#  {u'pushes': 3198215, u'repository_language': u'C++'},
#  {u'pushes': 2687386, u'repository_language': u'C'},
#  {u'pushes': 1894286, u'repository_language': u'Shell'},
#  {u'pushes': 1545896, u'repository_language': u'C#'},
#  {u'pushes': 941452, u'repository_language': u'Objective-C'},
#  {u'pushes': 523566, u'repository_language': u'Go'},
#  {u'pushes': 479152, u'repository_language': u'VimL'},
#  {u'pushes': 464709, u'repository_language': u'Perl'},
#  {u'pushes': 462860, u'repository_language': u'R'},
#  {u'pushes': 422087, u'repository_language': u'TeX'},
#  {u'pushes': 382327, u'repository_language': u'CoffeeScript'},
#  {u'pushes': 376564, u'repository_language': u'Scala'},
#  {u'pushes': 266847, u'repository_language': u'Lua'},
#  {u'pushes': 242452, u'repository_language': u'Haskell'},
#  {u'pushes': 230289, u'repository_language': u'Emacs Lisp'},
#  {u'pushes': 174239, u'repository_language': u'Clojure'},
#  {u'pushes': 155331, u'repository_language': u'Matlab'},
#  {u'pushes': 142313, u'repository_language': u'Groovy'},
#  {u'pushes': 142150, u'repository_language': u'Puppet'}]

# %% [markdown]
# ## The Pushes

# %% [markdown]
# This query retrieves the push events from the timeline. Notice the reference to `popular_languages` in the query. The SQL for this query is embedded inline, allowing you to compose complex queries _before_ the query is sent to BigQuery for processing.

# %%
# %%bq_sql pushes
# SELECT timeline.actor AS user,
#        timeline.repository_language AS language,
#        COUNT(timeline.repository_language) AS pushes
# FROM [githubarchive:github.timeline] AS timeline
# JOIN $popular_languages AS languages
#   ON timeline.repository_language = languages.repository_language
# WHERE type = 'PushEvent'
#   AND PARSE_UTC_USEC(created_at) >=
#       DATE_ADD(CURRENT_TIMESTAMP(), -1, 'YEAR')
# GROUP BY user, language

# %% [markdown]
# The `pushes` query was also only defined; it hasn't been processed yet. The following query builds on it further to add sampling to further reduce the resultset, specifically to limit it to a 5% sample. Notice the use of BigQuery's built-in hashing function to perform the sampling.

# %%
# %%bq_sql sampled_pushes
# SELECT user, language, pushes
# FROM $pushes
# WHERE ABS(HASH(user)) % 100 < 5

# %% [markdown]
# # Analyzing the Data

# %% [markdown]
# The next step is to integrate the BigQuery SQL queries with the analysis capabilities provided by python and pandas. The query defined earlier can be easily materialized into a pandas dataframe.

# %%
df = sampled_pushes.results().to_dataframe()
len(df)
# Out:
# 111819

# %% [markdown]
# We got a resultset of just over 100K data points, from the last years worth of commits across the top-25 programming languages. And a small sample of the first 10 results...

# %%
df[:10]
# Out:
#      language  pushes         user
# 0         C++    1106   bytemaster
# 1           C     840       minggo
# 2  JavaScript      31    rockSandy
# 3  JavaScript     106   SeanMarcia
# 4        Ruby      90      RanSolo
# 5         CSS      11       stdare
# 6         C++     208        dicej
# 7         CSS      29   jaredmoody
# 8        Ruby      73  hadibadjian
# 9        Java      10    cloudchou

# %% [markdown]
# Great, so we've successfully populated a Pandas dataframe with our dataset. Let's dig into our dataset a little further using the dataframe to see if our data makes sense.
#
# First, let's see how many unique users exist within our dataset and also see who is the user with the most distinct languages.  We can do that by looking at the `users` column of our dataframe.

# %%
summary = df['user'].describe()
print 'Dataset contains', summary['count'], 'rows with', summary['unique'], 'unique users'
print 'The user with the most distinct languages is', summary['top'], 'with', summary['freq'], 'distinct languages'
# Out:
# Dataset contains 111819 rows with 63060 unique users
# The user with the most distinct languages is gregnietsky with 17 distinct languages

# %% [markdown]
# Let's see the particular languages this user has pushed code for.

# %%
print 'Languages used by', summary['top']
df[df['user'] == summary['top']]
# Out:
# Languages used by gregnietsky
#            language  pushes         user
# 636             PHP     110  gregnietsky
# 1529              C    8920  gregnietsky
# 1553            C++    2187  gregnietsky
# 1566    Objective-C      33  gregnietsky
# 1582          Shell     999  gregnietsky
# 1597     JavaScript      36  gregnietsky
# 3800         Python     608  gregnietsky
# 3844           Java     298  gregnietsky
# 13849          Ruby     108  gregnietsky
# 14273            Go       4  gregnietsky
# 14285    Emacs Lisp     146  gregnietsky
# 15971            C#      91  gregnietsky
# 16002          Perl     130  gregnietsky
# 18112           CSS      34  gregnietsky
# 32317             R       1  gregnietsky
# 36666           TeX      26  gregnietsky
# 109885          Lua       2  gregnietsky

# %% [markdown]
# ## Reshaping the Data

# %% [markdown]
# The results we have so far, have multiple rows for each user. Specifically, one per language. The next step is to pivot that data, so we have one row per user, and one column per language. The resulting matrix will be extremely sparse. We'll just fill in 0, as in no pushes, for user/language pairs that have no data.
#
# Pandas offers a built-in `pivot()` method, which helps here.

# %%
dfp = df.pivot(index = 'user', columns = 'language', values = 'pushes').fillna(0)
dfp
# Out:
# language            C  C#  C++  CSS  Clojure  CoffeeScript  Emacs Lisp  Go  \
# user
# 000014h             0   0    0    0        0             0           0   0
# 0003                0   0    0    0        0             0           0   0
# 0065paula           0   0    0   13        0             0           0   0
# 008agent            5  12    2    0        0             0           0   0
# 00Christina         0   0    0    0        0             0           0   0
# 00StevenG           0   0    0    0        0             0           0   0
# 0102                0   0    0    0        0             0           0   0
# 0110              209   0    0    0        0             0           0   0
# 01d55               0   0    1    0        0             0           0   0
# 01es                0   0    0    0        0             0           0   0
# 01esha              0   0    0    0        0             0           0   0
# 01gaunte            0   0    0    0        0             0           0   0
# 02110917            0   0    0    0        0             0           0   0
# 0325189             0   0    0    0        0             0           0   0
# 03731               1   0    0    0        0             0           0   0
# 03knoppg            0   2    0    0        0             0           0   0
# 03lafaye            0   0    0    0        0             0           0   0
# 040378c0            0   0    0    0        0             0           0   0
# 0486zhc             0   0    0    0        0             0           0   0
# 051                 0   0    0    0        0             0           0   0
# 05K4R               0   0    0    0        0             0           0   0
# 05lindne            0   0    1    0        0             0           0   0
# 0607chris           0   0    0    0        0             0           0   0
# 0612800232          0   0    0    0        0             0           0   0
# 061375              0   0    0    0        0             0           0   0
# 06peng              0   0    0    0        0             0           0   0
# 0878685             0   0    0    0        0             0           0   0
# 09jhoward           0   0    0    0        0             0           0   0
# 09liweis            0   0    0    1        0             0           0   0
# 0VAN                0   0    0    0        0             0           0   0
# ...               ...  ..  ...  ...      ...           ...         ...  ..
# zynne               0   0    0    0        0             0           0   0
# zyr                 0   0    0    6        0             0           0   0
# zyt144              0   0    0    0        0             0           0   0
# zytal               0   0    0    0        0             0           0   0
# zyuce               0   0    0    0        0             0           0   0
# zyxakarene          0   0    0    0        0             0           0   0
# zyzlik              0   0    0    1        0             0           0   0
# zzaewon             0   0    0    0        0             0           0   0
# zzambushzz          0   0    0    2        0             0           0   0
# zzapal              0   0    0    0        0             0           0   0
# zzcworld            2   0    0    0        0             0           0   0
# zzdobrusky          0   0    0    0        0             0           0   0
# zzf03680147         0   0    0    0        0             0           0   0
# zzh1989829          0   0    5    1        0             0           0   0
# zzh2005             0   0    0    0        0             0           0   0
# zzhou               0   0    0    0        0             0           0   0
# zzimdak             0   0    0    0        0             0           0   0
# zzltjnh             1   0    4    0        0             0           0   0
# zzmax               0   0    0    0        0             0           0   0
# zzn1227             0   0    0    4        0             0           0   0
# zzongaly            0   0    4    0        0             0           0   0
# zzoon              11   0    0    0        0             0           0   0
# zzorn               4   0    0    0        0             0           0   0
# zzq1015             0   0    0    0        0             0           0   0
# zzs213              0   0    0    0        0             0           0   0
# zzxwill             0   0    0    0        0             0           0   0
# zzzili              0   0    0    0        0             0           0   0
# zzzjojo1            0   0    0    0        0             0           0   0
# zzzzzzzzzzzzz       0   0    0    0        0             0           0   0
# zzzzzzzzzzzzzzzz    0   0    0    1        0             0           0   0
#
# language          Groovy  Haskell  ...   PHP  Perl  Puppet  Python  R  Ruby  \
# user                               ...
# 000014h                0        0  ...     0     0       0       0  0     0
# 0003                   0        0  ...     0     0       0       8  0     0
# 0065paula              0        0  ...     0     0       0      23  0     0
# 008agent               0        0  ...     0     0       0       0  0     0
# 00Christina            0        0  ...     0     0       0       0  3     0
# 00StevenG              0        0  ...     0     0       0       0  0     0
# 0102                   0        0  ...     0     0       0       0  0     0
# 0110                   0        0  ...     0     0       0       0  0     0
# 01d55                  0        0  ...     0     0       0       0  0     0
# 01es                   0        0  ...     0     0       0       0  0     0
# 01esha                 0        0  ...     0     0       0       1  0     0
# 01gaunte               0        0  ...     0     0       0       4  0     0
# 02110917               0        0  ...     0     0       0       0  0     0
# 0325189                0        0  ...     0     0       0       0  0     0
# 03731                  0        0  ...     0     0       0       0  0     0
# 03knoppg               0        0  ...     0     0       0       0  0     0
# 03lafaye               0        0  ...     0     0       0      25  0     0
# 040378c0               0        0  ...     0     0       0       1  0     0
# 0486zhc                0        0  ...    23     0       0       0  0     0
# 051                    0        0  ...     0     0       0       0  0     0
# 05K4R                  0        0  ...     0     0       0       0  0     0
# 05lindne               0        0  ...     0     0       0       0  0     0
# 0607chris              0        0  ...     0     0       0       0  0     0
# 0612800232             0        0  ...     0     0       0       0  0     6
# 061375                 0        0  ...     2     0       0       0  0     0
# 06peng                 0        0  ...     0     0       0       0  0     0
# 0878685                0        0  ...     0     0       0       1  0     0
# 09jhoward              0        0  ...     0     0       0       2  0     0
# 09liweis               0        0  ...     0     0       0       0  0     0
# 0VAN                   0        0  ...     0     0       0      47  0     0
# ...                  ...      ...  ...   ...   ...     ...     ... ..   ...
# zynne                  0        0  ...     0     0       0       0  0     0
# zyr                    0        0  ...     0     0       0       0  0     0
# zyt144                 0        0  ...     5     0       0       1  0     0
# zytal                  0        0  ...     0     0       0       0  0     0
# zyuce                  0        0  ...     0     0       0       0  0     0
# zyxakarene             0        0  ...     0     0       0       0  0     0
# zyzlik                 0        0  ...     0     0       0       0  0     0
# zzaewon                0        0  ...     0     0       0       0  0     0
# zzambushzz             0        0  ...     0     0       0       0  0     0
# zzapal                 0        0  ...     0     0       0       0  0     0
# zzcworld               0        0  ...     0     0       0       0  0     0
# zzdobrusky             0        0  ...     0     0       0       0  0     0
# zzf03680147            0        0  ...     0     0       0       0  0     0
# zzh1989829             0        0  ...     0     0       0       0  0     0
# zzh2005                0        0  ...     0     0       0       0  0     0
# zzhou                  0        0  ...     0     0       0       8  0     0
# zzimdak                0        0  ...     0     0       0       0  0     0
# zzltjnh                0        0  ...     0     0       0       0  0     0
# zzmax                  0        0  ...     0     0       0       0  0     0
# zzn1227                0        0  ...     0     0       0       0  0     0
# zzongaly               0        0  ...     0     0       0       0  0     0
# zzoon                  0        0  ...     0     0       0       0  0     0
# zzorn                  2        0  ...     0     0       0       0  0     0
# zzq1015                0        0  ...     0     0       0       2  0     0
# zzs213                 0        0  ...     0     0       0       0  0     0
# zzxwill                0        0  ...     0     0       0       0  0     0
# zzzili                 0        0  ...     0     0       0       0  0     0
# zzzjojo1               0        0  ...     0     0       0       0  0     0
# zzzzzzzzzzzzz          0        0  ...     0     0       0       0  0     3
# zzzzzzzzzzzzzzzz       0        0  ...     0     0       0       0  0     0
#
# language          Scala  Shell  TeX  VimL
# user
# 000014h               0      0    0     0
# 0003                  0      0    0     0
# 0065paula             0      0    0     0
# 008agent              0      0    0     0
# 00Christina           0      0    0     0
# 00StevenG             0      0    0     0
# 0102                  0      0    0     6
# 0110                  0      0    0     0
# 01d55                 0      0    0     0
# 01es                  2      0    0     0
# 01esha                0      0    0     0
# 01gaunte              0      0    0     0
# 02110917              0      0    0     0
# 0325189               0      0    0     0
# 03731                 0      0    0     0
# 03knoppg              0      0    0     0
# 03lafaye              0      0    0     0
# 040378c0              0      0    0     0
# 0486zhc               0      0    0     0
# 051                   0      0    0     0
# 05K4R                 0      0    0     0
# 05lindne              0      0    0     0
# 0607chris             0      0    0     0
# 0612800232            0      0    0     0
# 061375                0      0    0     0
# 06peng                0      4    0     0
# 0878685               0      0    0     0
# 09jhoward             0      0    0     0
# 09liweis              0      0    0     0
# 0VAN                  0      0    0     0
# ...                 ...    ...  ...   ...
# zynne                 0      0    0     0
# zyr                   0      0    0     0
# zyt144                0      0    0     0
# zytal                 0      0    0     0
# zyuce                 0      0    0     0
# zyxakarene            0      0    0     0
# zyzlik                0      0    0     0
# zzaewon               0      0    0     0
# zzambushzz            0      0    0     0
# zzapal                0      0    0     0
# zzcworld              0      0    0     0
# zzdobrusky            0      0    0     0
# zzf03680147           0      0    0     0
# zzh1989829            0      0    0     0
# zzh2005               0      0    0     0
# zzhou                 0      0    0     0
# zzimdak               0      0    0     0
# zzltjnh               0      0    0     0
# zzmax                 0      0    0     0
# zzn1227               0      0    0     0
# zzongaly              0      0    0     0
# zzoon                 0      0    0     0
# zzorn                 4     32    0     0
# zzq1015               0      0    0     0
# zzs213                0      0    0     3
# zzxwill               0      0    0     0
# zzzili                0      0    0     0
# zzzjojo1              0      0    0     0
# zzzzzzzzzzzzz         0      0    0     0
# zzzzzzzzzzzzzzzz      0      0    0     0
#
# [63060 rows x 25 columns]

# %% [markdown]
# And then compute the correlation for each pair of languages, again, built-in into the pandas library.

# %%
corr = dfp.corr(method = 'spearman')
corr
# Out:
# language             C        C#       C++       CSS   Clojure  CoffeeScript  \
# language
# C             1.000000 -0.013573  0.214427 -0.030879  0.008110      0.015167
# C#           -0.013573  1.000000  0.006426 -0.048814 -0.003953      0.003016
# C++           0.214427  0.006426  1.000000 -0.050355  0.003895      0.006994
# CSS          -0.030879 -0.048814 -0.050355  1.000000  0.036327      0.088610
# Clojure       0.008110 -0.003953  0.003895  0.036327  1.000000      0.025298
# CoffeeScript  0.015167  0.003016  0.006994  0.088610  0.025298      1.000000
# Emacs Lisp    0.034814 -0.014225  0.033452  0.021165  0.140483      0.012851
# Go            0.034505 -0.009979  0.019198  0.041441  0.042975      0.054295
# Groovy       -0.003522 -0.010706 -0.012670  0.004474  0.007051      0.012198
# Haskell       0.045334 -0.004713  0.028689  0.010647  0.057879      0.035531
# Java         -0.026451 -0.049155 -0.037294 -0.075557  0.001680     -0.023909
# JavaScript   -0.041871 -0.007015 -0.057411  0.237931  0.038705      0.136291
# Lua           0.052707  0.010365  0.039948 -0.000042  0.005881      0.009196
# Matlab        0.026303 -0.007961  0.030881 -0.011069 -0.001687      0.000002
# Objective-C   0.018042 -0.011745  0.001274 -0.014655  0.003290      0.015328
# PHP          -0.053409 -0.051245 -0.065776  0.062394 -0.016616      0.003406
# Perl          0.053953 -0.013715  0.028024  0.017306  0.019439      0.015229
# Puppet        0.014157 -0.012216 -0.009276  0.019023  0.020534      0.015767
# Python        0.075165 -0.050905  0.062554  0.027987  0.020090      0.038428
# R            -0.034955 -0.040090 -0.041169 -0.050148  0.000204     -0.016809
# Ruby         -0.015405 -0.054903 -0.048405  0.105214  0.045026      0.096526
# Scala         0.000415 -0.010190 -0.006383  0.005199  0.024587      0.012319
# Shell         0.121333 -0.024976  0.050906  0.067284  0.050478      0.091193
# TeX           0.066770 -0.010878  0.061418  0.014323  0.016141      0.004919
# VimL          0.045671 -0.024742  0.030935  0.060084  0.053614      0.085654
#
# language      Emacs Lisp        Go    Groovy   Haskell    ...          PHP  \
# language                                                  ...
# C               0.034814  0.034505 -0.003522  0.045334    ...    -0.053409
# C#             -0.014225 -0.009979 -0.010706 -0.004713    ...    -0.051245
# C++             0.033452  0.019198 -0.012670  0.028689    ...    -0.065776
# CSS             0.021165  0.041441  0.004474  0.010647    ...     0.062394
# Clojure         0.140483  0.042975  0.007051  0.057879    ...    -0.016616
# CoffeeScript    0.012851  0.054295  0.012198  0.035531    ...     0.003406
# Emacs Lisp      1.000000  0.052143 -0.003747  0.080511    ...    -0.013571
# Go              0.052143  1.000000  0.008604  0.033263    ...    -0.007103
# Groovy         -0.003747  0.008604  1.000000  0.008042    ...    -0.023130
# Haskell         0.080511  0.033263  0.008042  1.000000    ...    -0.017424
# Java           -0.018358 -0.013468  0.100010 -0.006136    ...    -0.109344
# JavaScript      0.011150  0.036886 -0.001017  0.016410    ...     0.037040
# Lua             0.025942  0.029263  0.006076  0.016354    ...    -0.005940
# Matlab          0.008265 -0.005491 -0.002722  0.009423    ...    -0.026311
# Objective-C    -0.000391  0.010102 -0.005418 -0.003555    ...    -0.038015
# PHP            -0.013571 -0.007103 -0.023130 -0.017424    ...     1.000000
# Perl            0.032147  0.027445  0.003875  0.008331    ...     0.004516
# Puppet          0.006095  0.026454  0.004303 -0.001356    ...     0.024740
# Python          0.044483  0.058524 -0.002797  0.042019    ...    -0.056314
# R              -0.007150 -0.014983 -0.009525 -0.007019    ...    -0.060892
# Ruby            0.034779  0.064600  0.001449  0.018901    ...    -0.045852
# Scala           0.017573  0.031988  0.040624  0.049086    ...    -0.023130
# Shell           0.089071  0.104616  0.048375  0.050293    ...     0.015660
# TeX             0.029778  0.016855  0.001457  0.055496    ...    -0.022748
# VimL            0.038363  0.077869  0.000536  0.060670    ...     0.000935
#
# language          Perl    Puppet    Python         R      Ruby     Scala  \
# language
# C             0.053953  0.014157  0.075165 -0.034955 -0.015405  0.000415
# C#           -0.013715 -0.012216 -0.050905 -0.040090 -0.054903 -0.010190
# C++           0.028024 -0.009276  0.062554 -0.041169 -0.048405 -0.006383
# CSS           0.017306  0.019023  0.027987 -0.050148  0.105214  0.005199
# Clojure       0.019439  0.020534  0.020090  0.000204  0.045026  0.024587
# CoffeeScript  0.015229  0.015767  0.038428 -0.016809  0.096526  0.012319
# Emacs Lisp    0.032147  0.006095  0.044483 -0.007150  0.034779  0.017573
# Go            0.027445  0.026454  0.058524 -0.014983  0.064600  0.031988
# Groovy        0.003875  0.004303 -0.002797 -0.009525  0.001449  0.040624
# Haskell       0.008331 -0.001356  0.042019 -0.007019  0.018901  0.049086
# Java         -0.016557 -0.013128 -0.064983 -0.073429 -0.096086  0.042433
# JavaScript    0.013788  0.015162  0.021000 -0.075029  0.077626  0.016609
# Lua           0.021895  0.009855  0.026382 -0.011708  0.006989 -0.001733
# Matlab       -0.001247 -0.004306  0.033384  0.019633 -0.020852  0.007138
# Objective-C  -0.001649 -0.007789 -0.020708 -0.033659  0.019045 -0.010831
# PHP           0.004516  0.024740 -0.056314 -0.060892 -0.045852 -0.023130
# Perl          1.000000  0.034865  0.046961  0.000616  0.026009  0.005605
# Puppet        0.034865  1.000000  0.033445 -0.013673  0.087648  0.003818
# Python        0.046961  0.033445  1.000000 -0.025172 -0.011932  0.015567
# R             0.000616 -0.013673 -0.025172  1.000000 -0.049353 -0.000216
# Ruby          0.026009  0.087648 -0.011932 -0.049353  1.000000  0.003278
# Scala         0.005605  0.003818  0.015567 -0.000216  0.003278  1.000000
# Shell         0.093863  0.098752  0.129822 -0.027740  0.103936  0.051521
# TeX           0.030862  0.001091  0.079754  0.031344 -0.003660  0.012376
# VimL          0.058596  0.044625  0.082296 -0.019003  0.099019  0.025079
#
# language         Shell       TeX      VimL
# language
# C             0.121333  0.066770  0.045671
# C#           -0.024976 -0.010878 -0.024742
# C++           0.050906  0.061418  0.030935
# CSS           0.067284  0.014323  0.060084
# Clojure       0.050478  0.016141  0.053614
# CoffeeScript  0.091193  0.004919  0.085654
# Emacs Lisp    0.089071  0.029778  0.038363
# Go            0.104616  0.016855  0.077869
# Groovy        0.048375  0.001457  0.000536
# Haskell       0.050293  0.055496  0.060670
# Java         -0.002358  0.002878 -0.041406
# JavaScript    0.070885 -0.001183  0.058872
# Lua           0.050323  0.017164  0.037015
# Matlab       -0.001551  0.059928 -0.000832
# Objective-C  -0.001054 -0.002426  0.000981
# PHP           0.015660 -0.022748  0.000935
# Perl          0.093863  0.030862  0.058596
# Puppet        0.098752  0.001091  0.044625
# Python        0.129822  0.079754  0.082296
# R            -0.027740  0.031344 -0.019003
# Ruby          0.103936 -0.003660  0.099019
# Scala         0.051521  0.012376  0.025079
# Shell         1.000000  0.052471  0.192919
# TeX           0.052471  1.000000  0.036766
# VimL          0.192919  0.036766  1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# # Visualizing the Data and Analysis Results

# %% [markdown]
# ## Finding language correlations

# %% [markdown]
# The correlation table above contains all the results, but isn't very telling. A plot will make the data speak a lot louder, and highlight the highly correlated languages, as well as highly uncorrelated languages.

# %%
# Plotting helper function
def plot_correlation(data):
    min_value = 0
    max_value = 0

    for i in range(len(data.columns)):
        for j in range(len(data.columns)):
            if i != j:
                min_value = min(min_value, data.iloc[i, j])
                max_value = max(max_value, data.iloc[i, j])
    span = max(abs(min_value), abs(max_value))
    span = round(span + .05, 1)

    items = data.columns.tolist()
    ticks = np.arange(0.5, len(items) + 0.5)

    plot.figure(figsize = (11, 7))
    plot.pcolor(data.values, cmap = 'RdBu', vmin = -span, vmax = span)
    plot.colorbar().set_label('correlation')
    plot.xticks(ticks, items, rotation = 'vertical')
    plot.yticks(ticks, items)
    plot.show()

# %%
plot_correlation(corr)

# %% [markdown]
# We can see that JavaScript and HTML pushes have strong positive correlation, as well as C and C++ (good sanity check).

# %% [markdown]
# ## Building a language map

# %% [markdown]
# We can take this a step further by computing the [principal components](http://en.wikipedia.org/wiki/Principal_component_analysis) of our correlation matrix. We can do this easily within our notebook like so:

# %%
from matplotlib.mlab import PCA
pcs = PCA(corr)
pc1, pc2 = pcs.Y[:,1], pcs.Y[:,2]

# %% [markdown]
# Now let's plot the first two principal components, representing each language as a point in our PCA space.  This allows us to get a high-level "map" of how the languages relate to one another.  Similar languages will appear as nearby points within this map.  Here we go.

# %%
fig, ax = plot.subplots()
fig.set_size_inches(12, 12)

ax.scatter(pc1, pc2, alpha=0)
for i, language in enumerate(corr.columns):
    ax.annotate(language, (pc1[i], pc2[i]))

plot.xlabel('1st Principal Component')
plot.ylabel('2nd Principal Component')

# %% [markdown]
# We can immediately see that again, C and C++ are closely related (nearby in the diagram), indicating that developers that commit code in C to GitHub tend to also commit code in C++; Python appears as a near-neighbor.
#
# Unsurprisingly, we see the JVM languages form a small cluster in the top-right (Java, Groovy, Scala) with Clojure bridging the gap with (Emacs) Lisp.

# %% [markdown]
# # Insights and Take-aways

# %% [markdown]
# On programming language correlation:
#
# * No surprise ... JavaScript is highly correlated with CSS, and C with C++
# * Bit surprising ... Java has some strong uncorrelations - with JavaScript, PHP and Ruby ... static vs. dynamic languages?
# * Also surpriseing ... R seems not so correlated with Python?
# * Go is not uncorrelated with anything, even if not highly correlated. Go programmers do not exclusively program in Go.
# * And PHP is uncorrelated with many languages. Maybe a different developer persona.
#
# ---
#
# This notebook demonstrated integrating BigQuery SQL queries, and python data analysis and visualization to work against the large GitHub timeline data to extract some insights and patterns around some programming languages and their respective communities.
