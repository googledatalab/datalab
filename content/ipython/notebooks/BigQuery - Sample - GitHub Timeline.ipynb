# %% [markdown]
# # BigQuery - Sample - GitHub Timeline
#
# This notebook demonstrates working with GitHub activity made possible via the publicly accessible GitHub Timeline BigQuery dataset via the [GitHub Archive project](http://www.githubarchive.org/).
#
# As an interesting question, it attempts to determine "_how likely are you to program in X, if you program in Y_." For example, this might be an input into an repository exploration/recommendation/search tool to personalize the results based on your own contributions.
#
# It is based on an example published at http://datahackermd.com/2013/language-use-on-github/. It counts pushes or commits made by all users across all repositories on GitHub, and their associated repository languages, to determine the correlation between languages.
#
# ### In this notebook you will
# * Explore the BigQuery data schema for the Github Archive via the `gcp.bigquery` library
# * Use the `%%bq_sql` statement to write and execute SQL statements within the notebook
# * Extract data from BigQuery and create a local dataset that can be manipulated in Python
# * Refine and pivot your local dataset via the Pandas Python library
# * Visualize different aspects of your dataset via the Matplotlib Python library
#
# Related Links:
#
# * [BigQuery](https://cloud.google.com/bigquery/)
# * BigQuery [SQL reference](https://cloud.google.com/bigquery/query-reference)
# * Python [Pandas](http://pandas.pydata.org/) for data analysis
# * Python [matplotlib](http://matplotlib.org/) for data visualization
#
#
# ----
#
# NOTE:
#
# * The notebooks contains a snapshot of results (as of Oct 28th 2014) from previously executed code. You can simply read through the code and results, or execute each cell along the way, to get latest results.
# * For an introduction to BigQuery and notebook basics, see the [full list](..) of intro notebooks.
#
# ----

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import gcp.bigquery as bq

# %% [markdown]
# # Understanding the Data

# %% [markdown]
# We're going to work with the GitHub Archive project data.  It contains all github events (commits, pushes, forks, watches, etc.) along with metadata about the events (e.g., user, time, place).
#
# First, lets check out the table schema.

# %% [markdown]
# ## Schema

# %%
table = bq.table('githubarchive:github.timeline')
table.schema()
# Out:
# [<gcp.bigquery._table._Field at 0x10b8572d0>,
#  <gcp.bigquery._table._Field at 0x10b857290>,
#  <gcp.bigquery._table._Field at 0x10b857250>,
#  <gcp.bigquery._table._Field at 0x10b857210>,
#  <gcp.bigquery._table._Field at 0x10b8571d0>,
#  <gcp.bigquery._table._Field at 0x10b857190>,
#  <gcp.bigquery._table._Field at 0x10b857150>,
#  <gcp.bigquery._table._Field at 0x10b857110>,
#  <gcp.bigquery._table._Field at 0x10b857950>,
#  <gcp.bigquery._table._Field at 0x10b857990>,
#  <gcp.bigquery._table._Field at 0x10b8579d0>,
#  <gcp.bigquery._table._Field at 0x10b857a10>,
#  <gcp.bigquery._table._Field at 0x10b857a50>,
#  <gcp.bigquery._table._Field at 0x10b857a90>,
#  <gcp.bigquery._table._Field at 0x10b857ad0>,
#  <gcp.bigquery._table._Field at 0x10b857b10>,
#  <gcp.bigquery._table._Field at 0x10b857b50>,
#  <gcp.bigquery._table._Field at 0x10b857b90>,
#  <gcp.bigquery._table._Field at 0x10b857bd0>,
#  <gcp.bigquery._table._Field at 0x10b857c10>,
#  <gcp.bigquery._table._Field at 0x10b857c50>,
#  <gcp.bigquery._table._Field at 0x10b857c90>,
#  <gcp.bigquery._table._Field at 0x10b857cd0>,
#  <gcp.bigquery._table._Field at 0x10b857d10>,
#  <gcp.bigquery._table._Field at 0x10b857d50>,
#  <gcp.bigquery._table._Field at 0x10b857d90>,
#  <gcp.bigquery._table._Field at 0x10b857dd0>,
#  <gcp.bigquery._table._Field at 0x10b857e10>,
#  <gcp.bigquery._table._Field at 0x10b857e50>,
#  <gcp.bigquery._table._Field at 0x10b857e90>,
#  <gcp.bigquery._table._Field at 0x10b857ed0>,
#  <gcp.bigquery._table._Field at 0x10b857f10>,
#  <gcp.bigquery._table._Field at 0x10b857f50>,
#  <gcp.bigquery._table._Field at 0x10b857f90>,
#  <gcp.bigquery._table._Field at 0x10b857fd0>,
#  <gcp.bigquery._table._Field at 0x10bdb3050>,
#  <gcp.bigquery._table._Field at 0x10bdb3090>,
#  <gcp.bigquery._table._Field at 0x10bdb30d0>,
#  <gcp.bigquery._table._Field at 0x10bdb3110>,
#  <gcp.bigquery._table._Field at 0x10bdb3150>,
#  <gcp.bigquery._table._Field at 0x10bdb3190>,
#  <gcp.bigquery._table._Field at 0x10bdb31d0>,
#  <gcp.bigquery._table._Field at 0x10bdb3210>,
#  <gcp.bigquery._table._Field at 0x10bdb3250>,
#  <gcp.bigquery._table._Field at 0x10bdb3290>,
#  <gcp.bigquery._table._Field at 0x10bdb32d0>,
#  <gcp.bigquery._table._Field at 0x10bdb3310>,
#  <gcp.bigquery._table._Field at 0x10bdb3350>,
#  <gcp.bigquery._table._Field at 0x10bdb3390>,
#  <gcp.bigquery._table._Field at 0x10bdb33d0>,
#  <gcp.bigquery._table._Field at 0x10bdb3410>,
#  <gcp.bigquery._table._Field at 0x10bdb3450>,
#  <gcp.bigquery._table._Field at 0x10bdb3490>,
#  <gcp.bigquery._table._Field at 0x10bdb34d0>,
#  <gcp.bigquery._table._Field at 0x10bdb3510>,
#  <gcp.bigquery._table._Field at 0x10bdb3550>,
#  <gcp.bigquery._table._Field at 0x10bdb3590>,
#  <gcp.bigquery._table._Field at 0x10bdb35d0>,
#  <gcp.bigquery._table._Field at 0x10bdb3610>,
#  <gcp.bigquery._table._Field at 0x10bdb3650>,
#  <gcp.bigquery._table._Field at 0x10bdb3690>,
#  <gcp.bigquery._table._Field at 0x10bdb36d0>,
#  <gcp.bigquery._table._Field at 0x10bdb3710>,
#  <gcp.bigquery._table._Field at 0x10bdb3750>,
#  <gcp.bigquery._table._Field at 0x10bdb3790>,
#  <gcp.bigquery._table._Field at 0x10bdb37d0>,
#  <gcp.bigquery._table._Field at 0x10bdb3810>,
#  <gcp.bigquery._table._Field at 0x10bdb3850>,
#  <gcp.bigquery._table._Field at 0x10bdb3890>,
#  <gcp.bigquery._table._Field at 0x10bdb38d0>,
#  <gcp.bigquery._table._Field at 0x10bdb3910>,
#  <gcp.bigquery._table._Field at 0x10bdb3950>,
#  <gcp.bigquery._table._Field at 0x10bdb3990>,
#  <gcp.bigquery._table._Field at 0x10bdb39d0>,
#  <gcp.bigquery._table._Field at 0x10bdb3a10>,
#  <gcp.bigquery._table._Field at 0x10bdb3a50>,
#  <gcp.bigquery._table._Field at 0x10bdb3a90>,
#  <gcp.bigquery._table._Field at 0x10bdb3ad0>,
#  <gcp.bigquery._table._Field at 0x10bdb3b10>,
#  <gcp.bigquery._table._Field at 0x10bdb3b50>,
#  <gcp.bigquery._table._Field at 0x10bdb3b90>,
#  <gcp.bigquery._table._Field at 0x10bdb3bd0>,
#  <gcp.bigquery._table._Field at 0x10bdb3c10>,
#  <gcp.bigquery._table._Field at 0x10bdb3c50>,
#  <gcp.bigquery._table._Field at 0x10bdb3c90>,
#  <gcp.bigquery._table._Field at 0x10bdb3cd0>,
#  <gcp.bigquery._table._Field at 0x10bdb3d10>,
#  <gcp.bigquery._table._Field at 0x10bdb3d50>,
#  <gcp.bigquery._table._Field at 0x10bdb3d90>,
#  <gcp.bigquery._table._Field at 0x10bdb3dd0>,
#  <gcp.bigquery._table._Field at 0x10bdb3e10>,
#  <gcp.bigquery._table._Field at 0x10bdb3e50>,
#  <gcp.bigquery._table._Field at 0x10bdb3e90>,
#  <gcp.bigquery._table._Field at 0x10bdb3ed0>,
#  <gcp.bigquery._table._Field at 0x10bdb3f10>,
#  <gcp.bigquery._table._Field at 0x10bdb3f50>,
#  <gcp.bigquery._table._Field at 0x10bdb3f90>,
#  <gcp.bigquery._table._Field at 0x10bdb3fd0>,
#  <gcp.bigquery._table._Field at 0x10bdb4050>,
#  <gcp.bigquery._table._Field at 0x10bdb4090>,
#  <gcp.bigquery._table._Field at 0x10bdb40d0>,
#  <gcp.bigquery._table._Field at 0x10bdb4110>,
#  <gcp.bigquery._table._Field at 0x10bdb4150>,
#  <gcp.bigquery._table._Field at 0x10bdb4190>,
#  <gcp.bigquery._table._Field at 0x10bdb41d0>,
#  <gcp.bigquery._table._Field at 0x10bdb4210>,
#  <gcp.bigquery._table._Field at 0x10bdb4250>,
#  <gcp.bigquery._table._Field at 0x10bdb4290>,
#  <gcp.bigquery._table._Field at 0x10bdb42d0>,
#  <gcp.bigquery._table._Field at 0x10bdb4310>,
#  <gcp.bigquery._table._Field at 0x10bdb4350>,
#  <gcp.bigquery._table._Field at 0x10bdb4390>,
#  <gcp.bigquery._table._Field at 0x10bdb43d0>,
#  <gcp.bigquery._table._Field at 0x10bdb4410>,
#  <gcp.bigquery._table._Field at 0x10bdb4450>,
#  <gcp.bigquery._table._Field at 0x10bdb4490>,
#  <gcp.bigquery._table._Field at 0x10bdb44d0>,
#  <gcp.bigquery._table._Field at 0x10bdb4510>,
#  <gcp.bigquery._table._Field at 0x10bdb4550>,
#  <gcp.bigquery._table._Field at 0x10bdb4590>,
#  <gcp.bigquery._table._Field at 0x10bdb45d0>,
#  <gcp.bigquery._table._Field at 0x10bdb4610>,
#  <gcp.bigquery._table._Field at 0x10bdb4650>,
#  <gcp.bigquery._table._Field at 0x10bdb4690>,
#  <gcp.bigquery._table._Field at 0x10bdb46d0>,
#  <gcp.bigquery._table._Field at 0x10bdb4710>,
#  <gcp.bigquery._table._Field at 0x10bdb4750>,
#  <gcp.bigquery._table._Field at 0x10bdb4790>,
#  <gcp.bigquery._table._Field at 0x10bdb47d0>,
#  <gcp.bigquery._table._Field at 0x10bdb4810>,
#  <gcp.bigquery._table._Field at 0x10bdb4850>,
#  <gcp.bigquery._table._Field at 0x10bdb4890>,
#  <gcp.bigquery._table._Field at 0x10bdb48d0>,
#  <gcp.bigquery._table._Field at 0x10bdb4910>,
#  <gcp.bigquery._table._Field at 0x10bdb4950>,
#  <gcp.bigquery._table._Field at 0x10bdb4990>,
#  <gcp.bigquery._table._Field at 0x10bdb49d0>,
#  <gcp.bigquery._table._Field at 0x10bdb4a10>,
#  <gcp.bigquery._table._Field at 0x10bdb4a50>,
#  <gcp.bigquery._table._Field at 0x10bdb4a90>,
#  <gcp.bigquery._table._Field at 0x10bdb4ad0>,
#  <gcp.bigquery._table._Field at 0x10bdb4b10>,
#  <gcp.bigquery._table._Field at 0x10bdb4b50>,
#  <gcp.bigquery._table._Field at 0x10bdb4b90>,
#  <gcp.bigquery._table._Field at 0x10bdb4bd0>,
#  <gcp.bigquery._table._Field at 0x10bdb4c10>,
#  <gcp.bigquery._table._Field at 0x10bdb4c50>,
#  <gcp.bigquery._table._Field at 0x10bdb4c90>,
#  <gcp.bigquery._table._Field at 0x10bdb4cd0>,
#  <gcp.bigquery._table._Field at 0x10bdb4d10>,
#  <gcp.bigquery._table._Field at 0x10bdb4d50>,
#  <gcp.bigquery._table._Field at 0x10bdb4d90>,
#  <gcp.bigquery._table._Field at 0x10bdb4dd0>,
#  <gcp.bigquery._table._Field at 0x10bdb4e10>,
#  <gcp.bigquery._table._Field at 0x10bdb4e50>,
#  <gcp.bigquery._table._Field at 0x10bdb4e90>,
#  <gcp.bigquery._table._Field at 0x10bdb4ed0>,
#  <gcp.bigquery._table._Field at 0x10bdb4f10>,
#  <gcp.bigquery._table._Field at 0x10bdb4f50>,
#  <gcp.bigquery._table._Field at 0x10bdb4f90>,
#  <gcp.bigquery._table._Field at 0x10bdb4fd0>,
#  <gcp.bigquery._table._Field at 0x10bdb5050>,
#  <gcp.bigquery._table._Field at 0x10bdb5090>,
#  <gcp.bigquery._table._Field at 0x10bdb50d0>,
#  <gcp.bigquery._table._Field at 0x10bdb5110>,
#  <gcp.bigquery._table._Field at 0x10bdb5150>,
#  <gcp.bigquery._table._Field at 0x10bdb5190>,
#  <gcp.bigquery._table._Field at 0x10bdb51d0>,
#  <gcp.bigquery._table._Field at 0x10bdb5210>,
#  <gcp.bigquery._table._Field at 0x10bdb5250>,
#  <gcp.bigquery._table._Field at 0x10bdb5290>,
#  <gcp.bigquery._table._Field at 0x10bdb52d0>,
#  <gcp.bigquery._table._Field at 0x10bdb5310>,
#  <gcp.bigquery._table._Field at 0x10bdb5350>,
#  <gcp.bigquery._table._Field at 0x10bdb5390>,
#  <gcp.bigquery._table._Field at 0x10bdb53d0>,
#  <gcp.bigquery._table._Field at 0x10bdb5410>,
#  <gcp.bigquery._table._Field at 0x10bdb5450>,
#  <gcp.bigquery._table._Field at 0x10bdb5490>,
#  <gcp.bigquery._table._Field at 0x10bdb54d0>,
#  <gcp.bigquery._table._Field at 0x10bdb5510>,
#  <gcp.bigquery._table._Field at 0x10bdb5550>,
#  <gcp.bigquery._table._Field at 0x10bdb5590>,
#  <gcp.bigquery._table._Field at 0x10bdb55d0>,
#  <gcp.bigquery._table._Field at 0x10bdb5610>,
#  <gcp.bigquery._table._Field at 0x10bdb5650>,
#  <gcp.bigquery._table._Field at 0x10bdb5690>,
#  <gcp.bigquery._table._Field at 0x10bdb56d0>,
#  <gcp.bigquery._table._Field at 0x10bdb5710>,
#  <gcp.bigquery._table._Field at 0x10bdb5750>,
#  <gcp.bigquery._table._Field at 0x10bdb5790>,
#  <gcp.bigquery._table._Field at 0x10bdb57d0>,
#  <gcp.bigquery._table._Field at 0x10bdb5810>,
#  <gcp.bigquery._table._Field at 0x10bdb5850>,
#  <gcp.bigquery._table._Field at 0x10bdb5890>,
#  <gcp.bigquery._table._Field at 0x10bdb58d0>,
#  <gcp.bigquery._table._Field at 0x10bdb5910>,
#  <gcp.bigquery._table._Field at 0x10bdb5950>,
#  <gcp.bigquery._table._Field at 0x10bdb5990>]

# %% [markdown]
# The GitHub timeline is a fairly large dataset. A quick lookup of table metadata gives us the row count.

# %%
int(table.metadata().rows)
# Out:
# 263855065

# %% [markdown]
# ## Sampling the Data

# %% [markdown]
# With over 262 million events, it is important to be able to sample the data. The sample method allows you to sample tables, or queries.

# %%
table.sample(fields=['repository_name',
                     'repository_language',
                     'created_at',
                     'type'])
# Out:
# [{u'created_at': u'2014-06-11 13:05:31',
#   u'repository_language': None,
#   u'repository_name': u'miniquery',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-06-11 13:05:30',
#   u'repository_language': u'JavaScript',
#   u'repository_name': u'chap-links-library',
#   u'type': u'IssuesEvent'},
#  {u'created_at': u'2014-06-11 13:05:30',
#   u'repository_language': u'JavaScript',
#   u'repository_name': u'chap-links-library',
#   u'type': u'IssueCommentEvent'},
#  {u'created_at': u'2014-06-11 13:05:30',
#   u'repository_language': u'JavaScript',
#   u'repository_name': u'youtube-google-analytics',
#   u'type': u'ForkEvent'},
#  {u'created_at': u'2014-06-11 13:05:30',
#   u'repository_language': u'Objective-C',
#   u'repository_name': u'MailCore',
#   u'type': u'IssueCommentEvent'}]

# %% [markdown]
# ## Data Exploration with SQL

# %% [markdown]
# This SQL statement will pull a few interesting fields corresponding to repository creation events recorded in the GitHub timeline, ordered with most recent first.

# %%
# %%bq_sql
# SELECT repository_name, type, created_at, repository_language
# FROM [githubarchive:github.timeline]
# WHERE type = 'CreateEvent'
# ORDER BY created_at DESC
# LIMIT 5
# Out:
# [{u'created_at': u'2014-10-30 18:05:38',
#   u'repository_language': u'Ruby',
#   u'repository_name': u'etsydemo2',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-10-30 18:05:36',
#   u'repository_language': None,
#   u'repository_name': u'hvpc',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-10-30 18:05:35',
#   u'repository_language': u'CoffeeScript',
#   u'repository_name': u'node-lshift',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-10-30 18:05:34',
#   u'repository_language': u'Ruby',
#   u'repository_name': u'myapp',
#   u'type': u'CreateEvent'},
#  {u'created_at': u'2014-10-30 18:05:33',
#   u'repository_language': u'JavaScript',
#   u'repository_name': u'picturefill',
#   u'type': u'CreateEvent'}]

# %% [markdown]
# # Querying the Data

# %% [markdown]
# The first step in our analysis to correlate languages is going to be retrieving the appropriate slice of data.
#
# We'll need to retrieve the list of PushEvents from the timeline. This is going to be a fairly large list of events, so there are a couple of ways to get a more manageable resultset:
#
# * Limiting the analysis to the top 25 languages (from an otherwise really long list of languages which simply add noise).
# * Limiting the analysis to just pushes made during 1 year time window.
# * Further sampling to get a small, but still interesting sample set to analyze further for correlation.

# %% [markdown]
# ## Finding the Popular Languages

# %%
# %%bq_sql popular_languages
# SELECT repository_language, COUNT(repository_language) as pushes
# FROM [githubarchive:github.timeline]
# WHERE type = 'PushEvent'
#   AND repository_language != ''
#   AND PARSE_UTC_USEC(created_at) >= DATE_ADD(CURRENT_TIMESTAMP(), -1, 'YEAR')
# GROUP BY repository_language
# ORDER BY pushes DESC
# LIMIT 25

# %% [markdown]
# The `popular_languages` query defined above can be executed to see the results (as done below) or referenced in subsequent queries (as shown later).

# %%
popular_languages.results()
# Out:
# [{u'pushes': 10689943, u'repository_language': u'JavaScript'},
#  {u'pushes': 7168118, u'repository_language': u'Java'},
#  {u'pushes': 5620868, u'repository_language': u'Python'},
#  {u'pushes': 5319454, u'repository_language': u'CSS'},
#  {u'pushes': 4551917, u'repository_language': u'PHP'},
#  {u'pushes': 4273481, u'repository_language': u'Ruby'},
#  {u'pushes': 3198466, u'repository_language': u'C++'},
#  {u'pushes': 2687540, u'repository_language': u'C'},
#  {u'pushes': 1894421, u'repository_language': u'Shell'},
#  {u'pushes': 1546000, u'repository_language': u'C#'},
#  {u'pushes': 941523, u'repository_language': u'Objective-C'},
#  {u'pushes': 523596, u'repository_language': u'Go'},
#  {u'pushes': 479194, u'repository_language': u'VimL'},
#  {u'pushes': 464751, u'repository_language': u'Perl'},
#  {u'pushes': 462877, u'repository_language': u'R'},
#  {u'pushes': 422087, u'repository_language': u'TeX'},
#  {u'pushes': 382363, u'repository_language': u'CoffeeScript'},
#  {u'pushes': 376602, u'repository_language': u'Scala'},
#  {u'pushes': 266861, u'repository_language': u'Lua'},
#  {u'pushes': 242474, u'repository_language': u'Haskell'},
#  {u'pushes': 230298, u'repository_language': u'Emacs Lisp'},
#  {u'pushes': 174256, u'repository_language': u'Clojure'},
#  {u'pushes': 155349, u'repository_language': u'Matlab'},
#  {u'pushes': 142322, u'repository_language': u'Groovy'},
#  {u'pushes': 142163, u'repository_language': u'Puppet'}]

# %% [markdown]
# ## The Pushes

# %% [markdown]
# This query retrieves the push events from the timeline. Notice the reference to `popular_languages` in the query. The SQL for this query is embedded inline, allowing you to compose complex queries _before_ the query is sent to BigQuery for processing.

# %%
# %%bq_sql pushes
# SELECT timeline.actor AS user,
#        timeline.repository_language AS language,
#        COUNT(timeline.repository_language) AS pushes
# FROM [githubarchive:github.timeline] AS timeline
# JOIN $popular_languages AS languages
#   ON timeline.repository_language = languages.repository_language
# WHERE type = 'PushEvent'
#   AND PARSE_UTC_USEC(created_at) >=
#       DATE_ADD(CURRENT_TIMESTAMP(), -1, 'YEAR')
# GROUP BY user, language

# %% [markdown]
# The `pushes` query was also only defined; it hasn't been processed yet. The following query builds on it further to add sampling to further reduce the resultset, specifically to limit it to a 5% sample. Notice the use of BigQuery's built-in hashing function to perform the sampling.

# %%
# %%bq_sql sampled_pushes
# SELECT user, language, pushes
# FROM $pushes
# WHERE ABS(HASH(user)) % 100 < 5

# %% [markdown]
# # Analyzing the Data

# %% [markdown]
# The next step is to integrate the BigQuery SQL queries with the analysis capabilities provided by python and pandas. The query defined earlier can be easily materialized into a pandas dataframe.

# %%
df = sampled_pushes.results().to_dataframe()
len(df)
# Out:
# 111823

# %% [markdown]
# We got a resultset of just over 100K data points, from the last years worth of commits across the top-25 programming languages. And a small sample of the first 10 results...

# %%
df[:10]
# Out:
#       language  pushes           user
# 0          CSS     128  Charlie610790
# 1         Java      62        xuender
# 2         Java     198      rossfoley
# 3        Shell      73       pwendell
# 4   JavaScript      51           sdfb
# 5          CSS     133         sivers
# 6        Shell      11     superlukas
# 7         Java     535     gboissinot
# 8  Objective-C      24        YichiLL
# 9  Objective-C      43      kodayashi

# %% [markdown]
# Great, so we've successfully populated a Pandas dataframe with our dataset. Let's dig into our dataset a little further using the dataframe to see if our data makes sense.
#
# First, let's see how many unique users exist within our dataset and also see who is the user with the most distinct languages.  We can do that by looking at the `users` column of our dataframe.

# %%
summary = df['user'].describe()
print 'Dataset contains', summary['count'], 'rows with', summary['unique'], 'unique users'
print 'The user with the most distinct languages is', summary['top'], 'with', summary['freq'], 'distinct languages'
# Out:
# Dataset contains 111823 rows with 63062 unique users
# The user with the most distinct languages is gregnietsky with 17 distinct languages

# %% [markdown]
# Let's see the particular languages this user has pushed code for.

# %%
print 'Languages used by', summary['top']
df[df['user'] == summary['top']]
# Out:
# Languages used by gregnietsky
#            language  pushes         user
# 1854            C++    2187  gregnietsky
# 1857              C    8920  gregnietsky
# 6109            PHP     110  gregnietsky
# 6913             C#      91  gregnietsky
# 6925          Shell     999  gregnietsky
# 6987           Perl     130  gregnietsky
# 11442          Ruby     108  gregnietsky
# 11466          Java     298  gregnietsky
# 12441        Python     608  gregnietsky
# 16225    JavaScript      36  gregnietsky
# 17425   Objective-C      33  gregnietsky
# 28324           CSS      34  gregnietsky
# 45490    Emacs Lisp     146  gregnietsky
# 58675           TeX      26  gregnietsky
# 59502            Go       4  gregnietsky
# 102603            R       1  gregnietsky
# 111392          Lua       2  gregnietsky

# %% [markdown]
# ## Reshaping the Data

# %% [markdown]
# The results we have so far, have multiple rows for each user. Specifically, one per language. The next step is to pivot that data, so we have one row per user, and one column per language. The resulting matrix will be extremely sparse. We'll just fill in 0, as in no pushes, for user/language pairs that have no data.
#
# Pandas offers a built-in `pivot()` method, which helps here.

# zzzjojo1               0        0  ...     0     0       0       0  0     0
# zzzzzzzzzzzzz          0        0  ...     0     0       0       0  0     3
# zzzzzzzzzzzzzzzz       0        0  ...     0     0       0       0  0     0
#
# language          Scala  Shell  TeX  VimL
# user
# 000014h               0      0    0     0
# 0003                  0      0    0     0
# 0065paula             0      0    0     0
# 008agent              0      0    0     0
# 00Christina           0      0    0     0
# 00StevenG             0      0    0     0
# 0102                  0      0    0     6
# 0110                  0      0    0     0
# 01d55                 0      0    0     0
# 01es                  2      0    0     0
# 01esha                0      0    0     0
# 01gaunte              0      0    0     0
# 02110917              0      0    0     0
# 0325189               0      0    0     0
# 03731                 0      0    0     0
# 03knoppg              0      0    0     0
# 03lafaye              0      0    0     0
# 040378c0              0      0    0     0
# 0486zhc               0      0    0     0
# 051                   0      0    0     0
# 05K4R                 0      0    0     0
# 05lindne              0      0    0     0
# 0607chris             0      0    0     0
# 0612800232            0      0    0     0
# 061375                0      0    0     0
# 06peng                0      4    0     0
# 0878685               0      0    0     0
# 09jhoward             0      0    0     0
# 09liweis              0      0    0     0
# 0VAN                  0      0    0     0
# ...                 ...    ...  ...   ...
# zynne                 0      0    0     0
# zyr                   0      0    0     0
# zyt144                0      0    0     0
# zytal                 0      0    0     0
# zyuce                 0      0    0     0
# zyxakarene            0      0    0     0
# zyzlik                0      0    0     0
# zzaewon               0      0    0     0
# zzambushzz            0      0    0     0
# zzapal                0      0    0     0
# zzcworld              0      0    0     0
# zzdobrusky            0      0    0     0
# zzf03680147           0      0    0     0
# zzh1989829            0      0    0     0
# zzh2005               0      0    0     0
# zzhou                 0      0    0     0
# zzimdak               0      0    0     0
# zzltjnh               0      0    0     0
# zzmax                 0      0    0     0
# zzn1227               0      0    0     0
# zzongaly              0      0    0     0
# zzoon                 0      0    0     0
# zzorn                 4     32    0     0
# zzq1015               0      0    0     0
# zzs213                0      0    0     3
# zzxwill               0      0    0     0
# zzzili                0      0    0     0
# zzzjojo1              0      0    0     0
# zzzzzzzzzzzzz         0      0    0     0
# zzzzzzzzzzzzzzzz      0      0    0     0
#
# [63062 rows x 25 columns]

# %% [markdown]
# And then compute the correlation for each pair of languages, again, built-in into the pandas library.

# %%
corr = dfp.corr(method = 'spearman')
corr
# Out:
# language             C        C#       C++       CSS   Clojure  CoffeeScript  \
# language
# C             1.000000 -0.013571  0.214429 -0.030882  0.008111      0.015168
# C#           -0.013571  1.000000  0.006428 -0.048818 -0.003952      0.003017
# C++           0.214429  0.006428  1.000000 -0.050359  0.003896      0.006995
# CSS          -0.030882 -0.048818 -0.050359  1.000000  0.036325      0.088606
# Clojure       0.008111 -0.003952  0.003896  0.036325  1.000000      0.025299
# CoffeeScript  0.015168  0.003017  0.006995  0.088606  0.025299      1.000000
# Emacs Lisp    0.034814 -0.014224  0.033453  0.021162  0.140483      0.012851
# Go            0.034506 -0.009977  0.019199  0.041438  0.042975      0.054296
# Groovy       -0.003521 -0.010705 -0.012669  0.004473  0.007052      0.012198
# Haskell       0.045335 -0.004713  0.028690  0.010646  0.057879      0.035532
# Java         -0.026447 -0.049152 -0.037290 -0.075485  0.001681     -0.023907
# JavaScript   -0.041866 -0.007017 -0.057313  0.237896  0.038704      0.136287
# Lua           0.052708  0.010365  0.039949 -0.000043  0.005882      0.009196
# Matlab        0.026304 -0.007960  0.030882 -0.011070 -0.001687      0.000003
# Objective-C   0.018043 -0.011744  0.001277 -0.014659  0.003291      0.015329
# PHP          -0.053416 -0.051251 -0.065782  0.062366 -0.016618      0.003402
# Perl          0.053954 -0.013714  0.028028  0.017305  0.019454      0.015229
# Puppet        0.014158 -0.012215 -0.009275  0.019021  0.020535      0.015767
# Python        0.075167 -0.050902  0.062556  0.027980  0.020091      0.038428
# R            -0.034952 -0.040088 -0.041167 -0.050150  0.000204     -0.016809
# Ruby         -0.015401 -0.054899 -0.048393  0.105211  0.045025      0.096525
# Scala         0.000416 -0.010189 -0.006382  0.005197  0.024588      0.012319
# Shell         0.121309 -0.024986  0.050887  0.067244  0.050470      0.091180
# TeX           0.066771 -0.010876  0.061419  0.014320  0.016141      0.004920
# VimL          0.045673 -0.024741  0.030936  0.060080  0.053614      0.085655
#
# language      Emacs Lisp        Go    Groovy   Haskell    ...          PHP  \
# language                                                  ...
# C               0.034814  0.034506 -0.003521  0.045335    ...    -0.053416
# C#             -0.014224 -0.009977 -0.010705 -0.004713    ...    -0.051251
# C++             0.033453  0.019199 -0.012669  0.028690    ...    -0.065782
# CSS             0.021162  0.041438  0.004473  0.010646    ...     0.062366
# Clojure         0.140483  0.042975  0.007052  0.057879    ...    -0.016618
# CoffeeScript    0.012851  0.054296  0.012198  0.035532    ...     0.003402
# Emacs Lisp      1.000000  0.052143 -0.003747  0.080512    ...    -0.013573
# Go              0.052143  1.000000  0.008604  0.033263    ...    -0.007106
# Groovy         -0.003747  0.008604  1.000000  0.008042    ...    -0.023132
# Haskell         0.080512  0.033263  0.008042  1.000000    ...    -0.017426
# Java           -0.018357 -0.013466  0.100010 -0.006135    ...    -0.109356
# JavaScript      0.011149  0.036887 -0.001018  0.016409    ...     0.037013
# Lua             0.025943  0.029263  0.006076  0.016354    ...    -0.005943
# Matlab          0.008266 -0.005491 -0.002722  0.009424    ...    -0.026312
# Objective-C    -0.000390  0.010103 -0.005417 -0.003554    ...    -0.038020
# PHP            -0.013573 -0.007106 -0.023132 -0.017426    ...     1.000000
# Perl            0.032147  0.027445  0.003876  0.008331    ...     0.004512
# Puppet          0.006095  0.026454  0.004303 -0.001356    ...     0.024737
# Python          0.044483  0.058524 -0.002796  0.042019    ...    -0.056320
# R              -0.007150 -0.014982 -0.009524 -0.007019    ...    -0.060894
# Ruby            0.034779  0.064600  0.001449  0.018901    ...    -0.045862
# Scala           0.017573  0.031988  0.040624  0.049087    ...    -0.023133
# Shell           0.089059  0.104601  0.048366  0.050285    ...     0.015627
# TeX             0.029778  0.016856  0.001458  0.055497    ...    -0.022751
# VimL            0.038364  0.077871  0.000537  0.060673    ...     0.000930
#
# language          Perl    Puppet    Python         R      Ruby     Scala  \
.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# # Visualizing the Data and Analysis Results

# %% [markdown]
# The correlation table above contains all the results, but isn't very telling. A plot will make the data speak a lot louder, and highlight the highly correlated languages, as well as highly uncorrelated languages.

# %%
# Plotting helper function
def plot_correlation(data):
    min_value = 0
    max_value = 0

    for i in range(len(data.columns)):
        for j in range(len(data.columns)):
            if i != j:
                min_value = min(min_value, data.iloc[i, j])
                max_value = max(max_value, data.iloc[i, j])
    span = max(abs(min_value), abs(max_value))
    span = round(span + .05, 1)

    items = data.columns.tolist()
    ticks = np.arange(0.5, len(items) + 0.5)

    plot.figure(figsize = (11, 7))
    plot.pcolor(data.values, cmap = 'RdBu', vmin = -span, vmax = span)
    plot.colorbar().set_label('correlation')
    plot.xticks(ticks, items, rotation = 'vertical')
    plot.yticks(ticks, items)
    plot.show()

# %%
plot_correlation(corr)

# %% [markdown]
# We can see that JavaScript and HTML pushes have strong positive correlation, as well as C and C++ (good sanity check).
#
# Let's take a look at JavaScript in particular and see which languages are negatively correlated.

# %%
versus_javascript = corr['JavaScript'].order('ascending')
# Out:
# /Library/Python/2.7/site-packages/pandas/core/series.py:1743: FutureWarning: na_last is deprecated. Please use na_position instead
#   FutureWarning)

# %% [markdown]
# Let's remove JavaScript itself (by slicing the array as `foo[-1:]`) and plot these values as a simple bar chart.

# %%
versus_javascript[:-1].plot('barh')

# %% [markdown]
# We could do the same for any other language that we'd like to dive deeper into -- Go, for example.

# %%
corr['Go'].order('ascending', na_position='last')[:-1].plot('barh')

# %% [markdown]
# These 1-dimensional slices are informative, and allow us to see how a single language is correlated with other languages.
#
# ### A language relationship map
#
# We can take this a step further by computing the [principal components](http://en.wikipedia.org/wiki/Principal_component_analysis) of our correlation matrix. We can do this easily within our notebook like so:

# %%
from matplotlib.mlab import PCA
pcs = PCA(corr)
pc1, pc2 = pcs.Y[:,1], pcs.Y[:,2]

# %% [markdown]
# Now let's plot the first two principal components, representing each language as a point in our PCA space.  This allows us to get a high-level "map" of how the languages relate to one another.  Similar languages will appear as nearby points within this map.  Here we go.

# %%
fig, ax = plot.subplots()
fig.set_size_inches(12, 12)

ax.scatter(pc1, pc2, alpha=0)
for i, language in enumerate(corr.columns):
    ax.annotate(language, (pc1[i], pc2[i]))

plot.xlabel('1st Principal Component')
plot.ylabel('2nd Principal Component')

# %% [markdown]
# We can immediately see that again, C and C++ are closely related (nearby in the diagram); Python appears as a near-neighbor.
#
# Unsurprisingly, we see the JVM languages form a small cluster in the top-right (Java, Groovy, Scala) with Clojure bridging the gap with (Emacs) Lisp.

# %% [markdown]
# # Insights and Take-aways

# %% [markdown]
# On programming language correlation:
#
# * No surprise ... JavaScript is highly correlated with CSS, and C with C++
# * Bit surprising ... Java has some strong uncorrelations - with JavaScript, PHP and Ruby ... static vs. dynamic languages?
# * Also surpriseing ... R seems not so correlated with Python?
# * Go is not uncorrelated with anything, even if not highly correlated. Go programmers do not exclusively program in Go.
# * And PHP is uncorrelated with many languages. Maybe a different developer persona.
#
# ---
#
# This notebook demonstrated integrating BigQuery SQL queries, and python data analysis and visualization to work against the large GitHub timeline data to extract some insights and patterns around some programming languages and their respective communities.
